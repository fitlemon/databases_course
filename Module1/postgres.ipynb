# %% [markdown]
# Ранее мы уже говорили, что PostgreSQL — реляционная база данных с открытым кодом, одна из наиболее известных среди всех существующих реляционных баз данных.

# %% [markdown]
# ### Преимущества PostgreSQL:
#
# -    Объектно-реляционная модель. PostgreSQL — объектно-реляционная СУБД.
# -    Реляционной подход: данные представляются в виде записей, связанных друг с другом отношениями. Получаются связанные списки, которые могут иметь между собой те или иные отношения — так и образуется таблица.
# -    Объектный подход: данные представляются в виде объектов, их атрибутов, методов и классов как в ООП.
# -    Поддерживает большое количество типов данных.
# -    Работа с большими объемами.
# -    Поддерживает большее количество языков для написания собственных функций.
# -    Одновременная модификация базы. В PostgreSQL реализована клиент-серверная архитектура, когда база данных хранится на сервере, поэтому одновременно могут обратиться несколько пользователей к одной и той же базе данных.
# -    Соответствие ACID.
# -    Возможность расширения. Можно написать собственные типы и их преобразования, операции, функции, индексы.
# -    Высокая мощность и широкая функциональность.
# -    Открытый исходный код.
# -    Кроссплатформенность. PostgreSQL можно установить в системы на базе Linux, Windows, BSD, macOS и Solaris.

# %% [markdown]
# ### Установка PostgreSQL
#
# Начнем со скачивания дистрибутивов PostgreSQL с <a href="https://www.enterprisedb.com/downloads/postgres-postgresql-downloads">официального сайта.</a> Выбираем нужную операционную систему и последнюю версию PostgreSQL, устанавливаем.

# %% [markdown]
# ### Метакоманды PostgreSQL

# %% [markdown]
# Теперь, когда мы все настроили и готовы приступить к работе с базой данных, осталось разобрать несколько метакоманд. Это не SQL-запросы, а специфичные для PostgreSQL команды.

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-color:#9ABAD9;border-spacing:0;}
# .tg td{background-color:#EBF5FF;border-color:#9ABAD9;border-style:solid;border-width:1px;color:#444;
#   font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{background-color:#409cff;border-color:#9ABAD9;border-style:solid;border-width:1px;color:#fff;
#   font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-th5u{background-color:#88CDB2;border-color:inherit;color:#062425;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-jdhy{background-color:#96fffb;border-color:inherit;text-align:left;vertical-align:middle}
# .tg .tg-fymr{border-color:inherit;font-weight:bold;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-th5u">Команды</th>
#     <th class="tg-fymr">Описание</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-fymr">\l</td>
#     <td class="tg-jdhy">Вывод списка баз данных</td>
#   </tr>
#   <tr>
#     <td class="tg-fymr">\с «название базы данных»</td>
#     <td class="tg-jdhy">Подключение к базе данных</td>
#   </tr>
#   <tr>
#     <td class="tg-fymr">\dt</td>
#     <td class="tg-jdhy">Получить список всех таблиц в базе данных</td>
#   </tr>
#   <tr>
#     <td class="tg-fymr">\dg</td>
#     <td class="tg-jdhy">Получить список всех пользователей и ролей</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ### Установка DBeaver

# %% [markdown]
# После установки и настройки PostgreSQL необходимо решить, каким образом мы с ним будем работать. У пользователя есть два способа администрирования СУБД:
#
# -    Писать запросы через CLI.
# -    Использовать графический пользовательский интерфейс (GUI).
#
# Второй вариант намного удобнее, т. к. он позволяет повысить производительность.

# %% [markdown]
# <div style="background-color: #e0fff3; padding: 15px; color: black; width: 80%;">  <b>Графический интерфейс PostgreSQL </b>— это инструмент управления базами данных PostgreSQL. Он позволяет любому пользователю запрашивать и визуализировать данные, а также манипулировать данными и анализировать их. С его помощью можно получать доступ к серверам баз данных и перемещаться по ним.</div>

# %% [markdown]
# Одним из популярных GUI считается DBeaver, поэтому мы его скачаем и поработаем с ним.

# %% [markdown]
# DBeaver можно установить на Windows, macOS и Linux, скачав со страницы загрузки на <a href="https://dbeaver.io/download/">сайте разработчиков</a>.

# %% [markdown]
# Чтобы установить DBeaver, нужно:
#
#     Запустить установочный файл.
#     Выбрать язык и нажать кнопку OK.
#     Следовать указаниям программы.
#     Выбрать все компоненты программы и нажать «Далее».
#     Выбрать папку для установки программы.
#     Следовать указаниям установщика.
#     Дождаться окончания установки.
#     Нажать кнопку «Готово» для завершения установки.
#
# Открываем установленный DBeaver и подключаемся к созданной базе данных:

# %% [markdown]
# 1. Нажимаем на «База данных», выбираем «Новое соединение»:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Выбираем PostgreSQL и нажимаем «Далее»:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Вносим те же данные для хоста, порта, пользователя и нажимаем «Готово»:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Созданное соединение можно открыть, дважды щелкнув по нему в списке соединений.
#
# 5. Далее необходимо открыть редактор SQL и начать писать скрипты. Для этого нажимаем на панели сверху «Редактор SQL» и выбираем «Новый редактор SQL»:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. Откроется редактор, в котором как раз можно писать SQL-скрипты.
#
# 7. Создать базу данных, таблицу или добавить данные в таблицу можно одним из способов:
#
# -    через графический интерфейс;
# -    SQL-скриптом.
#
# 8. Создать базу данных можно с помощью команды CREATE DATABASE «название базы данных»:

# %% [markdown]
# 9. Удалить базу данных можно с помощью команды DROP DATABASE «название базы данных».

# %% [markdown]
# 10. Создать таблицу можно с помощью команды
# ```CREATE TABLE «название_таблицы».
# (название_столбца1 тип_данных атрибуты_столбца1,
#  название_столбца2 тип_данных атрибуты_столбца2,
#  ................................................
#  название_столбцаN тип_данных атрибуты_столбцаN,
#  атрибуты_таблицы
# );

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 11. Удалить таблицу можно с помощью команды DROP TABLE «название_таблицы».

# %% [markdown]
# ### Типы данных в PostgreSQL

# %% [markdown]
# Рассмотрим, какие типы данных существуют в PostgreSQL.

# %% [markdown]
# #### Числовые типы данных:

# %% [markdown]
# - serial: представляет автоинкрементирующееся числовое значение, которое занимает 4 байта и может хранить числа от 1 до 2 147 483 647. Значение данного типа образуется путем - - автоинкремента значения предыдущей строки. Поэтому, как правило, данный тип используется для определения идентификаторов строки.
# - smallint: хранит числа от -32 768 до +32 767. Занимает 2 байта. Имеет псевдоним int2.
# - integer: хранит числа от -2 147 483 648 до +2 147 483 647. Занимает 4 байта. Имеет псевдонимы int и int4.
# - bigint: хранит числа от -9 223 372 036 854 775 808 до +9 223 372 036 854 775 807. Занимает 8 байт. Имеет псевдоним int8.
#
# - numeric: хранит числа с фиксированной точностью, которые могут иметь до 131 072 знаков в целой части и до 16 383 знаков после запятой.

# %% [markdown]
# Данный тип может принимать два параметра precision и scale: numeric(precision, scale). Параметр precision указывает на максимальное количество цифр, которые может хранить число.
# - Параметр scale представляет максимальное количество цифр, которые может содержать число после запятой. Это значение должно находиться в диапазоне от 0 до значения параметра - - precision. По умолчанию оно равно 0. Например, для числа 23.5141 precision равно 6, а scale — 4.
# - decimal: хранит числа с фиксированной точностью, которые могут иметь до 131 072 знаков в целой части и до 16 383 знаков в дробной части. То же самое, что и numeric.
# - real: хранит числа с плавающей точкой из диапазона от 1E-37 до 1E+37. Занимает 4 байта. Имеет псевдоним float4.
# - double precision: хранит числа с плавающей точкой из диапазона от 1E-307 до 1E+308. Занимает 8 байт. Имеет псевдоним float8.

# %% [markdown]
# #### Символьные типы:

# %% [markdown]
# -    character(n): представляет строку из фиксированного количества символов. С помощью параметра задается количество символов в строке. Имеет псевдоним char(n).
# -    character varying(n): представляет строку из переменной длины. С помощью параметра задается максимальное количество символов в строке. Имеет псевдоним varchar(n).
# -    text: представляет текст произвольной длины.

# %% [markdown]
# Типы данных в PostgreSQL
#
# ### Числовые типы данных:
#
# 1. **serial**:
#    - Автоинкрементирующееся числовое значение.
#    - Занимает 4 байта.
#    - Диапазон: 1 до 2 147 483 647.
#    - Используется для идентификаторов строки.
#
# 2. **smallint** (int2):
#    - Занимает 2 байта.
#    - Диапазон: -32 768 до +32 767.
#
# 3. **integer** (int, int4):
#    - Занимает 4 байта.
#    - Диапазон: -2 147 483 648 до +2 147 483 647.
#
# 4. **bigint** (int8):
#    - Занимает 8 байт.
#    - Диапазон: -9 223 372 036 854 775 808 до +9 223 372 036 854 775 807.
#
# 5. **numeric**:
#    - Числа с фиксированной точностью.
#    - До 131 072 знаков в целой части и до 16 383 знаков после запятой.
#    - `numeric(precision, scale)`.
#
# 6. **decimal**:
#    - Аналогичен типу `numeric`.
#    - Числа с фиксированной точностью.
#
# 7. **real** (float4):
#    - Числа с плавающей точкой.
#    - Диапазон: 1E-37 до 1E+37.
#    - Занимает 4 байта.
#
# 8. **double precision** (float8):
#    - Числа с плавающей точкой.
#    - Диапазон: 1E-307 до 1E+308.
#    - Занимает 8 байт.
#
# ### Символьные типы:
#
# 1. **character(n)** (char(n)):
#    - Строка фиксированной длины.
#    - `n` задает количество символов.
#
# 2. **character varying(n)** (varchar(n)):
#    - Строка переменной длины.
#    - `n` задает максимальное количество символов.
#
# 3. **text**:
#    - Текст произвольной длины.
#
# ### Типы для работы с датами и временем:
#
# 1. **timestamp**:
#    - Хранит дату и время.
#    - Диапазон: 4713 г. до н. э. до 294 276 г. н. э.
#    - Занимает 8 байт.
#
# 2. **date**:
#    - Представляет дату.
#    - Диапазон: 4713 г. до н. э. до 5 874 897 г. н. э.
#    - Занимает 4 байта.
#
# 3. **time**:
#    - Хранит время до микросекунды.
#    - Диапазон: 00:00:00 до 24:00:00.
#    - Занимает 8 байт.
#
# 4. **interval**:
#    - Временной интервал.
#    - Занимает 16 байт.
#
# ### Логический тип:
#
# - **boolean**:
#   - Хранит `true` или `false`.
#
# ### Команда для добавления данных:
#
# ```sql
# INSERT INTO имя_таблицы (столбец1, столбец2, ... столбецN)
# VALUES (значение1, значение2, ... значениеN).
