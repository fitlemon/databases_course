# %% [markdown]
# # Выборка и агрегация данных в MongoDB
#
# ###Цель домашней работы
#
# Закрепить на практике основные приемы работы с СУБД MongoDB, включая выборку, сортировку, объединение, агрегацию данных и передачу результатов выборки в программу на Python в целях аналитики и дальнейшей обработки.

# %% [markdown]
# ### Формулировка задания
#
# В этом задании вам предстоит выполнить несколько запросов к базе данных для получения выборок по условиям, а также воспользоваться фреймворком агрегации MongoDB для построения конвейера обработки данных.
#
# Максимальное количество баллов за выполнение домашней работы: 10.

# %% [markdown]
# ##Что нужно использовать в работе над заданием
#
# I. MongoDB:
#
# 1. Зарегистрируйтесь в сервисе MongoDB Atlas: https://www.mongodb.com/atlas/database.
# 1. Создайте кластер уровня M0 (это бесплатно).
# 1. Добавьте в кластер тестовую базу данных `sample_mflix`, используя опцию Load Sample Dataset.
#
# В качестве альтернативы вы можете установить MongoDB на свой локальный компьютер и импортировать необходимые датасеты в свою СУБД, загрузив их по ссылке: https://github.com/neelabalan/mongodb-sample-dataset/tree/main/sample_mflix. Для этого подключитесь к своему серверу через Compass, создайте новую БД, создайте для каждого датасета коллекцию и щелкните «Add data» → «Import JSON or CSV file».
#
# II. MongoDB Compass — в качестве вспомогательного инструмента для конструирования запросов и агрегаций.
#
# III. Python и библиотека pymongo. Работа ведется в Jupyter Notebook или Google Colaboratory. Рекомендуется использовать версию Python 3.12.

# %% [markdown]
# ##Ожидаемые результаты
#
# Результаты работы необходимо оформить в виде ноутбука Jupyter. Можно загрузить файл в LMS либо поделиться ссылкой на Google Colaboratory.

# %% [markdown]
# ##Место где нужно выполнить задание

# %%
#Начать выполнение задания тут

# %%
# !pip install pymongo

import pymongo

client = pymongo.MongoClient("mongodb+srv://dikhmatullaev:suiTMW7n6IAo8j4U@cluster0.4z8kofw.mongodb.net/")
print(client.list_database_names())  # Вывести список БД для проверки подключения
# Out:
# Requirement already satisfied: pymongo in /home/fitlemon/code/databases_course/.venv/lib/python3.10/site-packages (4.6.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/fitlemon/code/databases_course/.venv/lib/python3.10/site-packages (from pymongo) (2.6.1)
# ['sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_guides', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %% [markdown]
# ### Упражнение 1. Запросы на выборку

# %% [markdown]
# Цель этого упражнения — закрепить навык выполнения запросов на выборку. Все запросы выполняются на базе `sample_mflix` с данными о кинофильмах.

# %% [markdown]
# #### Задача 1.1 — **1 балл**

# %% [markdown]
# Выведите из коллекции `theaters` документы о кинотеатрах в городе Florence, штат KY.
#
# Для справки:
#
# * Обратите внимание на то, что информация об адресе кинотеатров хранится во вложенных документах. Для доступа к полям вложенных документов следует использовать точку: `родительский_документ.вложенный_документ.поле`.
# * В случае затруднений с написанием логического условия обращайтесь к сопоставлению синтаксиса SQL и Mongo: https://www.mongodb.com/docs/manual/reference/sql-comparison/.
# * Если вы предпочитаете сперва выполнять запросы в Compass, из этого приложения можно выгружать код готового запроса на Python (кнопка с символом `</>`).

# %%
# Ваш код здесь
db = client.sample_mflix
result = db.theaters.find({'location.address.city': 'Florence', 'location.address.state': 'KY'})
list(result)
# Out:
# [{'_id': ObjectId('59a47287cfa9a3a73e51e893'),
#   'theaterId': 161,
#   'location': {'address': {'street1': '100 Meijer Dr.',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.636383, 39.014843]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ea02'),
#   'theaterId': 2823,
#   'location': {'address': {'street1': '2823 Florence Mall',
#     'street2': '#2148',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.6499595, 38.9967246]}}}]

# %% [markdown]
# #### Задача 1.2 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `comments`, выведите _один_ комментарий (значение поля `text`) пользователя по имени Doreah.

# %%
# Ваш код здесь
db = client.sample_mflix
result = db.comments.find_one({"name": {"$regex": "Doreah", "$options": "i"}})
result['text']
# Out:
# 'Porro explicabo cumque vitae sint quia quis. Consequuntur voluptatibus optio maxime ratione temporibus incidunt minus architecto.'

# %% [markdown]
# #### Задача 1.3 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `movies`, выведите количество документов, в которых в качестве первого жанра фильма (поле `genres`) указано значение «Horror».
#
# Для справки:
#
# 1. Обратите внимание, что поле `genres` представляет собой массив (индексация массивов начинается с нуля).
# 1. При работе в MongoDB Shell для подсчета количества документов в курсоре можно использовать метод `count()`, однако он был удален в последних версиях библиотеки pymongo. В случае затруднений с использованием функций Mongo можно использовать для подсчета документов средства Python.

# %%
# Ваш код здесь
db = client.sample_mflix
result = db.movies.find({'genres.0': 'Horror'})
count = 0
for item in result:
    count += 1
count
# Out:
# 700

# %% [markdown]
# #### Задача 1.4 — **2 балла**

# %% [markdown]
# Выведите из коллекции `movies` документы о фильмах, которые в качестве первого жанра определены как «Film-Noir» либо «Horror» и были выпущены в период с 1940 по 1949 гг. (включительно).

# %%
# Ваш код здесь
from datetime import datetime

db = client.sample_mflix
result = db.movies.find({'$or': [{'genres.0': 'Horror'}, {'genres.0': 'Film-Noir'}],'released': {'$gte': datetime(1940, 1, 1),'$lte': datetime(1949, 12, 31)}})
list(result)
# Out:
# [{'_id': ObjectId('573a1393f29313caabcdc814'),
#   'plot': "An American man marries a Serbian immigrant who fears that she will turn into the cat person of her homeland's fables if they are intimate together.",
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Simone Simon', 'Kent Smith', 'Tom Conway', 'Jane Randolph'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzI4YWY0NWQtNWI5YS00MGE4LWE4YTgtMzBmOWIwMzdiYTRiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Cat People',
#   'fullplot': 'Irena Dubrovna, a beautiful and mysterious Serbian-born fashion artist living in New York City, falls in love with and marries average-Joe American Oliver Reed. Their marriage suffers though, as Irena believes that she suffers from an ancient curse- whenever emotionally aroused, she will turn into a panther and kill. Oliver thinks that is absurd and childish, so he sends her to psychiatrist Dr. Judd to cure her. Easier said than done...',
#   'languages': ['English', 'Czech', 'Serbian'],
#   'released': datetime.datetime(1942, 12, 25, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['DeWitt Bodeen'],
#   'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'},
#   'lastupdated': '2015-08-21 00:53:54.453000000',
#   'year': 1942,
#   'imdb': {'rating': 7.4, 'votes': 11589, 'id': 34587},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 7115},
#    'critic': {'rating': 8.3, 'numReviews': 40, 'meter': 93},
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 3, 25),
#    'consensus': 'Influential noir director Jacques Tourneau infused this sexy, moody horror film with some sly commentary about the psychology and the taboos of desire.',
#    'rotten': 3,
#    'production': 'RKO Pictures',
#    'fresh': 37},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'plot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis ...',
#   'genres': ['Horror'],
#   'runtime': 69,
#   'rated': 'APPROVED',
#   'cast': ['James Ellison', 'Frances Dee', 'Tom Conway', 'Edith Barrett'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZjQzMzliN2YtYTVhNC00Zjc4LThjMmYtMTE0ZGUzMWNmYzJlXkEyXkFqcGdeQXVyMTYxNjkxOQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'I Walked with a Zombie',
#   'fullplot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis as a result of fever. When she falls in love with Paul, Betsy determines to cure Jessica even if she needs to use a voodoo ceremony, to give Paul what she thinks he wants.',
#   'languages': ['English'],
#   'released': datetime.datetime(1943, 4, 30, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Curt Siodmak (screenplay)',
#    'Ardel Wray (screenplay)',
#    'Inez Wallace (original story)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-16 00:16:16.823000000',
#   'year': 1943,
#   'imdb': {'rating': 7.3, 'votes': 6893, 'id': 36027},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 4884, 'meter': 75},
#    'dvd': datetime.datetime(2005, 10, 4, 0, 0),
#    'critic': {'rating': 8.1, 'numReviews': 26, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 16, 16),
#    'consensus': "Evocative direction by Jacques Tourneur collides with the low-rent production values of exploitateer Val Lewton in I Walked with a Zombie, a sultry sleeper that's simultaneously smarmy, eloquent and fascinating.",
#    'rotten': 2,
#    'production': 'Warner Home Video',
#    'fresh': 24}},
#  {'_id': ObjectId('573a1393f29313caabcdcdf5'),
#   'plot': 'A seemingly tame leopard used for a publicity stunt escapes and kills a young girl, spreading panic throughout a sleepy new Mexico town.',
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 66,
#   'rated': 'APPROVED',
#   'cast': ["Dennis O'Keefe", 'Margo', 'Jean Brooks', 'Isabel Jewell'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYmU4ZDI5NGMtYzM1OC00YTQ3LWI1NTEtNGM0Mzc0ZDA5NzI4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Leopard Man',
#   'fullplot': 'At the encouragement of her manager, a nightclub performer in New Mexico (Kiki Walker) takes a leashed leopard into the club as a publicity gimmick. But her rival, angered by the attempt to upstage, scares the animal and it bolts. In the days that follow, people are mauled and the countryside is combed for the loose creature. But Kiki and her manager begin to wonder if maybe the leopard is not responsible for the killings.',
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1943, 5, 8, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Ardel Wray (screenplay)',
#    'Edward Dein (additional dialogue)',
#    'Cornell Woolrich (novel)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-05 00:17:53.897000000',
#   'year': 1943,
#   'imdb': {'rating': 6.9, 'votes': 2889, 'id': 36104},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 1375, 'meter': 67},
#    'fresh': 15,
#    'critic': {'rating': 7.4, 'numReviews': 17, 'meter': 88},
#    'rotten': 2,
#    'lastUpdated': datetime.datetime(2015, 8, 27, 18, 6, 2)}},
#  {'_id': ObjectId('573a1393f29313caabcdd3ed'),
#   'plot': 'An architect senses impending doom as his half-remembered recurring dream turns into reality. The guests at the country house encourage him to stay as they take turns telling supernatural tales.',
#   'genres': ['Horror'],
#   'runtime': 77,
#   'rated': 'APPROVED',
#   'cast': ['Mervyn Johns', 'Roland Culver', 'Mary Merrall', 'Googie Withers'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTY2OTJjZjgtMzExMy00MWJlLTg2N2ItM2NhMDQxNTNkNjFhXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dead of Night',
#   'fullplot': "Architect Walter Craig, seeking the possibility of some work at a country farmhouse, soon finds himself once again stuck in his recurring nightmare. Dreading the end of the dream that he knows is coming, he must first listen to all the assembled guests' own bizarre tales.",
#   'languages': ['English', 'French'],
#   'released': datetime.datetime(1945, 10, 15, 0, 0),
#   'directors': ['Alberto Cavalcanti',
#    'Charles Crichton',
#    'Basil Dearden',
#    'Robert Hamer'],
#   'writers': ['H.G. Wells (original story)',
#    'E.F. Benson (original story)',
#    'John Baines (original story)',
#    'Angus MacPhail (original story)',
#    'John Baines (screenplay)',
#    'Angus MacPhail (screenplay)',
#    'T.E.B. Clarke (additional dialogue)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-09-15 04:38:12.500000000',
#   'year': 1945,
#   'imdb': {'rating': 7.7, 'votes': 7116, 'id': 37635},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3194, 'meter': 88},
#    'dvd': datetime.datetime(2009, 1, 27, 0, 0),
#    'critic': {'rating': 8.0, 'numReviews': 27, 'meter': 96},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 40, 43),
#    'consensus': 'With four accomplished directors contributing, Dead of Night is a classic horror anthology that remains highly influential.',
#    'rotten': 1,
#    'production': 'Universal Pictures',
#    'fresh': 26}},
#  {'_id': ObjectId('573a1393f29313caabcdd6e7'),
#   'plot': "Chuck Scott gets a job as chauffeur to tough guy Eddie Roman; but Chuck's involvement with Eddie's fearful wife becomes a nightmare.",
#   'genres': ['Film-Noir'],
#   'runtime': 86,
#   'rated': 'APPROVED',
#   'cast': ['Robert Cummings',
#    'Michèle Morgan',
#    'Steve Cochran',
#    'Lloyd Corrigan'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDI3OTM4NzMtNzQxMC00M2YxLWFmOTctNmUyNDBmMzIwZGI0XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Chase',
#   'fullplot': "Returning a lost wallet gains unemployed veteran Chuck Scott a job as chauffeur to Eddie Roman, a seeming gangster whose enemies have a way of meeting violent ends. The job proves nerve-wracking, and soon Chuck finds himself pledged to help Eddie's lovely, fearful, prisoner-wife Lorna to escape. The result leaves Chuck caught like a rat in a trap, vainly seeking a way out through dark streets. But the real chase begins when the strange plot virtually starts all over again...",
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1946, 11, 16, 0, 0),
#   'directors': ['Arthur Ripley'],
#   'writers': ['Philip Yordan (written for the screen by)',
#    'Cornell Woolrich (book)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-01 00:47:13.267000000',
#   'year': 1946,
#   'imdb': {'rating': 6.7, 'votes': 766, 'id': 38409},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 92, 'meter': 40},
#    'dvd': datetime.datetime(2003, 8, 5, 0, 0),
#    'production': 'VCI',
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 14, 48)}},
#  {'_id': ObjectId('573a1393f29313caabcde460'),
#   'plot': "Over-the-hill boxer Bill 'Stoker' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money ...",
#   'genres': ['Film-Noir', 'Sport'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Robert Ryan', 'Audrey Totter', 'George Tobias', 'Alan Baxter'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjEwNjU3NzE1Nl5BMl5BanBnXkFtZTgwMjQ0MDgyMTE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Set-Up',
#   'fullplot': 'Over-the-hill boxer Bill \'Stoker\' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money for a "dive" from tough gambler Little Boy...without bothering to tell Stoker. Tension builds as Stoker hopes to "take" Tiger Nelson, unaware of what will happen to him if he does.',
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 4, 2, 0, 0),
#   'directors': ['Robert Wise'],
#   'writers': ['Art Cohn (screenplay)',
#    'Joseph Moncure March (from the poem by)'],
#   'awards': {'wins': 3,
#    'nominations': 1,
#    'text': 'Nominated for 1 BAFTA Film Award. Another 2 wins & 1 nomination.'},
#   'lastupdated': '2015-08-26 00:13:18.837000000',
#   'year': 1949,
#   'imdb': {'rating': 7.8, 'votes': 5309, 'id': 41859},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 1692, 'meter': 88},
#    'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#    'critic': {'rating': 5.9, 'numReviews': 7, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 33, 52),
#    'rotten': 1,
#    'fresh': 6}}]

# %% [markdown]
# #### Задача 1.5 — **1 балл**

# %% [markdown]
# Модифицируйте запрос из задачи 1.4 таким образом, чтобы осуществить _проекцию_: результатом выборки должен стать список словарей, каждый из которых содержит только два поля: `title` и `year`.
#
# Для справки о проекции см. документацию по методу `find()` в pymongo:
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.find

# %%
# Ваш код здесь
db = client.sample_mflix
query = {'$or': [{'genres.0': 'Horror'}, {'genres.0': 'Film-Noir'}],'released': {'$gte': datetime(1940, 1, 1),'$lte': datetime(1949, 12, 31)}}
result = db.movies.find(query, projection={'title': '$title', 'year': '$year', '_id': 0})
list(result)
# Out:
# [{'title': 'Cat People', 'year': 1942},
#  {'title': 'I Walked with a Zombie', 'year': 1943},
#  {'title': 'The Leopard Man', 'year': 1943},
#  {'title': 'Dead of Night', 'year': 1945},
#  {'title': 'The Chase', 'year': 1946},
#  {'title': 'The Set-Up', 'year': 1949}]

# %% [markdown]
# ### Упражнение 2. Конвейер агрегации

# %% [markdown]
# #### Задача 2.1 — **3 балла**

# %% [markdown]
# В рамках этой задачи требуется узнать, какие фильмы получили наибольшее число комментариев. Составьте для этого конвейер агрегации с перечисленными ниже этапами. Для удобства рекомендуется воспользоваться приложением Compass.
#
# 1. Сгруппировать документы коллекции `comments` по полю `movie_id` и подсчитать количество комментариев для каждого фильма, записав его в поле `count`.
# 1. Отсортировать получившийся набор данных по убыванию количества комментариев (так чтобы первый документ в этом наборе указывал на фильм с наибольшим количеством комментариев).
# 1. Используя оператор `$lookup`, присоединить коллекцию `movies` (по полю `movie_id`).
# 1. Выполнить проекцию, оставив в наборе данных только три поля: название фильма (`title`), год выпуска (`year`) и количество комментариев (поле `count`, добавленное на первом этапе). Для этого воспользуйтесь оператором `$project`: https://www.mongodb.com/docs/manual/reference/operator/aggregation/project/. Обратите внимание, что данные из коллекции `movies` (`title` и `year`) на этом этапе окажутся внутри массива.
# 1. Применить оператор `$unwind`, чтобы деконструировать этот массив. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/. В результате массив должен превратиться в одиночный объект.
# 1. Применить оператор `$addFields`, чтобы добавить поля `title` и `year` на вернхий уровень структуры документа. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/addFields/.
# 1. Еще раз выполнить проекцию, чтобы удалить поле с массивом.
#
# Ваш алгоритм решения может отличаться от приведенного здесь. Главное — достичь цели: получить плоский набор данных с тремя полями (`count` — количество комментариев, `year` — год выпуска, `title` — название фильма).
#
# Скопируйте полученный конвейер в этот документ в виде кода на Python и выведите его на экран в виде списка словарей.

# %%
# Ваш код здесь
query = [{
        '$group': {
            '_id': '$movie_id', 
            'count': {
                '$count': {}
            }
        }
    }, {
        '$sort': {
            'count': -1
        }
    }, {
        '$lookup': {
            'from': 'movies', 
            'localField': '_id', 
            'foreignField': '_id', 
            'as': 'movie_doc'
        }
    }, {
        '$project': {
            'movie_doc': {
                'title': 1, 
                'year': 1
            }, 
            'count': 1
        }
    }, {
        '$unwind': {
            'path': '$movie_doc'
        }
    }, {
        '$addFields': {
            'title': '$movie_doc.title', 
            'year': '$movie_doc.year'
        }
    }, {
        '$project': {
 "title": "$title", 
  "year": "$year", 
  "count" : "$count",
  "_id": 0
}
    }
]
result = client['sample_mflix']['comments'].aggregate(query)
list(result)
# Out:
# [{'title': 'The Taking of Pelham 1 2 3', 'year': 2009, 'count': 161},
#  {'title': 'About a Boy', 'year': 2002, 'count': 158},
#  {'title': '50 First Dates', 'year': 2004, 'count': 158},
#  {'title': 'Terminator Salvation', 'year': 2009, 'count': 158},
#  {'title': "Ocean's Eleven", 'year': 2001, 'count': 158},
#  {'title': 'The Mummy', 'year': 1999, 'count': 157},
#  {'title': 'Sherlock Holmes', 'year': 2009, 'count': 157},
#  {'title': 'Hellboy II: The Golden Army', 'year': 2008, 'count': 155},
#  {'title': 'The Mummy Returns', 'year': 2001, 'count': 154},
#  {'title': 'Anchorman: The Legend of Ron Burgundy',
#   'year': 2004,
#   'count': 154},
#  {'title': 'X-Men', 'year': 2000, 'count': 153},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'year': 2007,
#   'count': 153},
#  {'title': 'E.T. the Extra-Terrestrial', 'year': 1982, 'count': 153},
#  {'title': 'Cinderella', 'year': 1950, 'count': 153},
#  {'title': 'American Pie', 'year': 1999, 'count': 153},
#  {'title': 'Wanted', 'year': 2008, 'count': 153},
#  {'title': 'Mission: Impossible', 'year': 1996, 'count': 153},
#  {'title': 'Bruce Almighty', 'year': 2003, 'count': 153},
#  {'title': 'The Ring', 'year': 2002, 'count': 152},
#  {'title': 'Gladiator', 'year': 2000, 'count': 152},
#  {'title': 'The Mask', 'year': 1994, 'count': 151},
#  {'title': 'The Matrix Reloaded', 'year': 2003, 'count': 151},
#  {'title': 'Meet the Fockers', 'year': 2004, 'count': 151},
#  {'title': 'Toy Story 2', 'year': 1999, 'count': 150},
#  {'title': 'Big Daddy', 'year': 1999, 'count': 150},
#  {'title': 'Jurassic Park', 'year': 1993, 'count': 148},
#  {'title': 'Braveheart', 'year': 1995, 'count': 148},
#  {'title': 'I Am Legend', 'year': 2007, 'count': 148},
#  {'title': 'Scary Movie', 'year': 2000, 'count': 147},
#  {'title': 'Jaws', 'year': 1975, 'count': 147},
#  {'title': 'The Express', 'year': 2008, 'count': 147},
#  {'title': 'I Now Pronounce You Chuck & Larry', 'year': 2007, 'count': 146},
#  {'title': 'Twister', 'year': 1996, 'count': 146},
#  {'title': 'Dumb & Dumber', 'year': 1994, 'count': 145},
#  {'title': 'Cast Away', 'year': 2000, 'count': 145},
#  {'title': '300', 'year': 2006, 'count': 145},
#  {'title': 'The Hangover', 'year': 2009, 'count': 144},
#  {'title': 'Spider-Man 3', 'year': 2007, 'count': 144},
#  {'title': 'Dègkeselyè', 'year': 1982, 'count': 144},
#  {'title': 'I Love You, Man', 'year': 2009, 'count': 144},
#  {'title': 'Aladdin', 'year': 1992, 'count': 144},
#  {'title': 'Hostel: Part II', 'year': 2007, 'count': 144},
#  {'title': 'King Kong', 'year': 2005, 'count': 144},
#  {'title': 'School of Rock', 'year': 2003, 'count': 144},
#  {'title': 'The Green Mile', 'year': 1999, 'count': 144},
#  {'title': 'The Last House on the Left', 'year': 2009, 'count': 144},
#  {'title': 'Zoolander', 'year': 2001, 'count': 144},
#  {'title': 'Saving Private Ryan', 'year': 1998, 'count': 144},
#  {'title': 'The Simpsons Movie', 'year': 2007, 'count': 144},
#  {'title': 'Up', 'year': 2009, 'count': 143},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002,
#   'count': 143},
#  {'title': 'The Jungle Creature: Hugo', 'year': 1993, 'count': 143},
#  {'title': 'Ice Age', 'year': 2002, 'count': 143},
#  {'title': 'Rush Hour 2', 'year': 2001, 'count': 143},
#  {'title': 'Kill Bill: Vol. 1', 'year': 2003, 'count': 143},
#  {'title': '8 Mile', 'year': 2002, 'count': 143},
#  {'title': 'Star Trek', 'year': 2009, 'count': 142},
#  {'title': 'Shutter Island', 'year': 2010, 'count': 142},
#  {'title': 'Speed', 'year': 1994, 'count': 142},
#  {'title': 'Back to the Future Part II', 'year': 1989, 'count': 142},
#  {'title': "Ocean's Twelve", 'year': 2004, 'count': 142},
#  {'title': 'Billy Madison', 'year': 1995, 'count': 141},
#  {'title': '1408', 'year': 2007, 'count': 141},
#  {'title': 'Live Free or Die Hard', 'year': 2007, 'count': 141},
#  {'title': 'Evan Almighty', 'year': 2007, 'count': 141},
#  {'title': 'The Princess Diaries', 'year': 2001, 'count': 141},
#  {'title': 'Rush Hour', 'year': 1998, 'count': 141},
#  {'title': 'Freaky Friday', 'year': 2003, 'count': 141},
#  {'title': 'X-Men 2', 'year': 2003, 'count': 140},
#  {'title': 'The Bourne Ultimatum', 'year': 2007, 'count': 140},
#  {'title': 'Back to the Future Part III', 'year': 1990, 'count': 140},
#  {'title': 'Cheaper by the Dozen', 'year': 2003, 'count': 140},
#  {'title': 'Mr. & Mrs. Smith', 'year': 2005, 'count': 140},
#  {'title': 'Men in Black II', 'year': 2002, 'count': 140},
#  {'title': 'Ghost Rider', 'year': 2007, 'count': 140},
#  {'title': 'War of the Worlds', 'year': 2005, 'count': 140},
#  {'title': 'V for Vendetta', 'year': 2005, 'count': 139},
#  {'title': 'Ace Ventura: When Nature Calls', 'year': 1995, 'count': 139},
#  {'title': 'The Wizard of Oz', 'year': 1939, 'count': 139},
#  {'title': 'Saw VI', 'year': 2009, 'count': 139},
#  {'title': 'Liar Liar', 'year': 1997, 'count': 139},
#  {'title': 'Happy Gilmore', 'year': 1996, 'count': 139},
#  {'title': 'The Matrix Revolutions', 'year': 2003, 'count': 139},
#  {'title': 'Sweeney Todd: The Demon Barber of Fleet Street',
#   'year': 2007,
#   'count': 138},
#  {'title': 'Gone in Sixty Seconds', 'year': 2000, 'count': 138},
#  {'title': 'A Christmas Carol', 'year': 2009, 'count': 138},
#  {'title': 'Men in Black 3', 'year': 2012, 'count': 138},
#  {'title': 'The Matrix', 'year': 1999, 'count': 138},
#  {'title': 'Donnie Darko', 'year': 2001, 'count': 138},
#  {'title': "Harry Potter and the Sorcerer's Stone",
#   'year': 2001,
#   'count': 138},
#  {'title': 'How to Lose a Guy in 10 Days', 'year': 2003, 'count': 138},
#  {'title': 'How the Grinch Stole Christmas', 'year': 2000, 'count': 138},
#  {'title': 'Shark Tale', 'year': 2004, 'count': 138},
#  {'title': 'Independence Day', 'year': 1996, 'count': 137},
#  {'title': 'My Big Fat Greek Wedding', 'year': 2002, 'count': 137},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005,
#   'count': 137},
#  {'title': 'Fight Club', 'year': 1999, 'count': 137},
#  {'title': 'The 40-Year-Old Virgin', 'year': 2005, 'count': 137},
#  {'title': 'Elf', 'year': 2003, 'count': 137},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004,
#   'count': 136},
#  {'title': 'Beetlejuice', 'year': 1988, 'count': 136},
#  {'title': 'Rocky', 'year': 1976, 'count': 136},
#  {'title': 'Forrest Gump', 'year': 1994, 'count': 136},
#  {'title': 'The Waterboy', 'year': 1998, 'count': 136},
#  {'title': 'The Dark Knight', 'year': 2008, 'count': 136},
#  {'title': 'Cast Away', 'year': 2000, 'count': 136},
#  {'title': 'The Nightmare Before Christmas', 'year': 1993, 'count': 136},
#  {'title': 'The Bourne Identity', 'year': 2002, 'count': 136},
#  {'title': 'Push', 'year': 2009, 'count': 135},
#  {'title': 'Indiana Jones and the Last Crusade', 'year': 1989, 'count': 135},
#  {'title': 'Signs', 'year': 2002, 'count': 135},
#  {'title': 'Honey, I Shrunk the Kids', 'year': 1989, 'count': 135},
#  {'title': 'Bring It On', 'year': 2000, 'count': 135},
#  {'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'year': 2005,
#   'count': 135},
#  {'title': 'Transformers: Revenge of the Fallen', 'year': 2009, 'count': 134},
#  {'title': 'Sin City', 'year': 2005, 'count': 134},
#  {'title': 'Miss Congeniality', 'year': 2000, 'count': 134},
#  {'title': 'Monsters, Inc.', 'year': 2001, 'count': 134},
#  {'title': 'The Jungle Book', 'year': 1967, 'count': 134},
#  {'title': 'Spider-Man 2', 'year': 2004, 'count': 134},
#  {'title': 'The Uninvited', 'year': 2009, 'count': 134},
#  {'title': 'Beauty and the Beast', 'year': 1991, 'count': 134},
#  {'title': 'Fantastic 4: Rise of the Silver Surfer',
#   'year': 2007,
#   'count': 134},
#  {'title': 'Fantastic Four', 'year': 2005, 'count': 134},
#  {'title': 'American Pie 2', 'year': 2001, 'count': 134},
#  {'title': 'The Mummy', 'year': 1999, 'count': 134},
#  {'title': 'The Ugly Truth', 'year': 2009, 'count': 133},
#  {'title': 'Blades of Glory', 'year': 2007, 'count': 133},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'year': 2003,
#   'count': 133},
#  {'title': 'The Fast and the Furious', 'year': 2001, 'count': 133},
#  {'title': 'Shrek 2', 'year': 2004, 'count': 133},
#  {'title': 'Free Willy', 'year': 1993, 'count': 132},
#  {'title': 'Men in Black', 'year': 1997, 'count': 132},
#  {'title': 'The Lion King', 'year': 1994, 'count': 132},
#  {'title': 'Catch Me If You Can', 'year': 2002, 'count': 132},
#  {'title': '2 Fast 2 Furious', 'year': 2003, 'count': 132},
#  {'title': 'Shrek the Third', 'year': 2007, 'count': 132},
#  {'title': "The Time Traveler's Wife", 'year': 2009, 'count': 132},
#  {'title': 'Ace Ventura: Pet Detective', 'year': 1994, 'count': 132},
#  {'title': 'Shark Tale', 'year': 2004, 'count': 131},
#  {'title': 'Toy Story', 'year': 1995, 'count': 131},
#  {'title': 'The Godfather', 'year': 1972, 'count': 131},
#  {'title': 'Shrek', 'year': 2001, 'count': 131},
#  {'title': 'The Unborn', 'year': 2009, 'count': 131},
#  {'title': 'The Sixth Sense', 'year': 1999, 'count': 131},
#  {'title': 'Doctor Dolittle', 'year': 1998, 'count': 131},
#  {'title': 'The Shawshank Redemption', 'year': 1994, 'count': 131},
#  {'title': 'Drag Me to Hell', 'year': 2009, 'count': 131},
#  {'title': 'American Beauty', 'year': 1999, 'count': 131},
#  {'title': 'Meet the Parents', 'year': 2000, 'count': 131},
#  {'title': 'Star Wars: Episode IV - A New Hope', 'year': 1977, 'count': 131},
#  {'title': 'Hook', 'year': 1991, 'count': 130},
#  {'title': 'Home Alone', 'year': 1990, 'count': 130},
#  {'title': 'Ice Age: The Meltdown', 'year': 2006, 'count': 130},
#  {'title': 'The Day After Tomorrow', 'year': 2004, 'count': 130},
#  {'title': 'Pretty Woman', 'year': 1990, 'count': 130},
#  {'title': 'G.I. Joe: The Rise of Cobra', 'year': 2009, 'count': 130},
#  {'title': 'Bad Boys', 'year': 1995, 'count': 129},
#  {'title': 'The Dark Knight Rises', 'year': 2012, 'count': 129},
#  {'title': 'Avatar', 'year': 2009, 'count': 129},
#  {'title': 'The Little Mermaid', 'year': 1989, 'count': 128},
#  {'title': 'Stop-Loss', 'year': 2008, 'count': 128},
#  {'title': 'A Walk to Remember', 'year': 2002, 'count': 128},
#  {'title': 'Liar Liar', 'year': 1997, 'count': 128},
#  {'title': 'A Cinderella Story', 'year': 2004, 'count': 128},
#  {'title': 'Austin Powers: International Man of Mystery',
#   'year': 1997,
#   'count': 128},
#  {'title': 'Sister Act', 'year': 1992, 'count': 128},
#  {'title': 'Mary Poppins', 'year': 1964, 'count': 128},
#  {'title': 'X-Men', 'year': 2000, 'count': 128},
#  {'title': 'Night at the Museum', 'year': 2006, 'count': 128},
#  {'title': 'The Curious Case of Benjamin Button', 'year': 2008, 'count': 128},
#  {'title': 'Titanic', 'year': 1997, 'count': 128},
#  {'title': 'Mr. Deeds', 'year': 2002, 'count': 128},
#  {'title': 'Troy', 'year': 2004, 'count': 128},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'year': 2002,
#   'count': 127},
#  {'title': 'The Wedding Singer', 'year': 1998, 'count': 127},
#  {'title': 'Inglourious Basterds', 'year': 2009, 'count': 127},
#  {'title': 'Funny People', 'year': 2009, 'count': 127},
#  {'title': 'Taken', 'year': 2008, 'count': 127},
#  {'title': 'Slumdog Millionaire', 'year': 2008, 'count': 127},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003,
#   'count': 127},
#  {'title': 'The Incredible Hulk', 'year': 2008, 'count': 127},
#  {'title': 'Raiders of the Lost Ark', 'year': 1981, 'count': 126},
#  {'title': 'Austin Powers in Goldmember', 'year': 2002, 'count': 126},
#  {'title': 'Mrs. Doubtfire', 'year': 1993, 'count': 126},
#  {'title': 'Anger Management', 'year': 2003, 'count': 126},
#  {'title': 'Lady and the Tramp', 'year': 1955, 'count': 126},
#  {'title': 'Terminator 2: Judgment Day', 'year': 1991, 'count': 125},
#  {'title': 'Pearl Harbor', 'year': 2001, 'count': 125},
#  {'title': 'Batman', 'year': 1989, 'count': 125},
#  {'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999,
#   'count': 124},
#  {'title': 'Armageddon', 'year': 1998, 'count': 124},
#  {'title': 'Scary Movie', 'year': 2000, 'count': 123},
#  {'title': 'National Treasure: Book of Secrets', 'year': 2007, 'count': 123},
#  {'title': 'Harry Potter and the Half-Blood Prince',
#   'year': 2009,
#   'count': 123},
#  {'title': 'Cars', 'year': 2006, 'count': 123},
#  {'title': "Ocean's Thirteen", 'year': 2007, 'count': 122},
#  {'title': 'The Stepfather', 'year': 2009, 'count': 122},
#  {'title': 'The Proposal', 'year': 2009, 'count': 122},
#  {'title': 'Fighting', 'year': 2009, 'count': 122},
#  {'title': 'The End of a Mystery', 'year': 2003, 'count': 122},
#  {'title': 'The Shawshank Redemption', 'year': 1994, 'count': 122},
#  {'title': 'Pulp Fiction', 'year': 1994, 'count': 121},
#  {'title': 'G-Force', 'year': 2009, 'count': 121},
#  {'title': 'The Silence of the Lambs', 'year': 1991, 'count': 121},
#  {'title': "A Bug's Life", 'year': 1998, 'count': 121},
#  {'title': 'Quarantine', 'year': 2008, 'count': 121},
#  {'title': 'The Invention of Lying', 'year': 2009, 'count': 121},
#  {'title': 'Madagascar', 'year': 2005, 'count': 121},
#  {'title': 'Willy Wonka & the Chocolate Factory', 'year': 1971, 'count': 120},
#  {'title': 'Finding Nemo', 'year': 2003, 'count': 120},
#  {'title': 'Harry Potter and the Goblet of Fire', 'year': 2005, 'count': 119},
#  {'title': 'The Hunger Games', 'year': 2012, 'count': 119},
#  {'title': 'Watchmen', 'year': 2009, 'count': 119},
#  {'title': 'Jumanji', 'year': 1995, 'count': 119},
#  {'title': '10 Things I Hate About You', 'year': 1999, 'count': 119},
#  {'title': 'Grease', 'year': 1978, 'count': 119},
#  {'title': '101 Dalmatians', 'year': 1961, 'count': 118},
#  {'title': 'Saw II', 'year': 2005, 'count': 117},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002,
#   'count': 117},
#  {'title': 'Orphan', 'year': 2009, 'count': 117},
#  {'title': 'The Avengers', 'year': 2012, 'count': 117},
#  {'title': 'Scary Movie 3', 'year': 2003, 'count': 116},
#  {'title': 'Love Actually', 'year': 2003, 'count': 116},
#  {'title': 'The Departed', 'year': 2006, 'count': 115},
#  {'title': 'Sweet Home Alabama', 'year': 2002, 'count': 115},
#  {'title': 'Dirty Dancing', 'year': 1987, 'count': 115},
#  {'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   'year': 2006,
#   'count': 115},
#  {'title': 'How to Lose a Guy in 10 Days', 'year': 2003, 'count': 115},
#  {'title': 'Edward Scissorhands', 'year': 1990, 'count': 115},
#  {'title': 'Scary Movie 2', 'year': 2001, 'count': 115},
#  {'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': 1980,
#   'count': 115},
#  {'title': 'Hairspray', 'year': 2007, 'count': 114},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'year': 2001,
#   'count': 114},
#  {'title': 'Disturbia', 'year': 2007, 'count': 113},
#  {'title': 'District 9', 'year': 2009, 'count': 111},
#  {'title': "Charlie's Angels", 'year': 2000, 'count': 111},
#  {'title': 'American Gangster', 'year': 2007, 'count': 111},
#  {'title': 'Coyote Ugly', 'year': 2000, 'count': 111},
#  {'title': 'The Amazing Spider-Man', 'year': 2012, 'count': 109},
#  {'title': 'Home Alone 2: Lost in New York', 'year': 1992, 'count': 108},
#  {'title': 'Norbit', 'year': 2007, 'count': 107},
#  {'title': 'The Cure', 'year': 1995, 'count': 5},
#  {'title': 'Play It Again, Sam', 'year': 1972, 'count': 4},
#  {'title': 'Splice', 'year': 2009, 'count': 4},
#  {'title': 'Compliance', 'year': 2012, 'count': 4},
#  {'title': 'The Women', 'year': 2008, 'count': 4},
#  {'title': 'Night Catches Us', 'year': 2010, 'count': 4},
#  {'title': 'Cowards Bend the Knee or The Blue Hands',
#   'year': 2003,
#   'count': 4},
#  {'title': 'Tired Moonlight', 'year': 2015, 'count': 3},
#  {'title': 'Jurassic Park III', 'year': 2001, 'count': 3},
#  {'title': 'Rabbit è la Berlin', 'year': 2009, 'count': 3},
#  {'title': 'Jibeuro ganeun gil', 'year': 2013, 'count': 3},
#  {'title': "The King's Speech", 'year': 2010, 'count': 3},
#  {'title': 'Deterrence', 'year': 1999, 'count': 3},
#  {'title': 'Mystery Men', 'year': 1999, 'count': 3},
#  {'title': 'The Roman Spring of Mrs. Stone', 'year': 1961, 'count': 3},
#  {'title': 'Without Men', 'year': 2011, 'count': 3},
#  {'title': 'Dig!', 'year': 2004, 'count': 3},
#  {'title': 'Syriana', 'year': 2005, 'count': 3},
#  {'title': '3 1/2 Minutes, Ten Bullets', 'year': 2015, 'count': 3},
#  {'title': 'Euridice BA 2O37', 'year': 1975, 'count': 3},
#  {'title': "Dead Man's Walk", 'year': 1996, 'count': 3},
#  {'title': 'The House', 'year': 1997, 'count': 3},
#  {'title': 'La Cage aux Folles', 'year': 1978, 'count': 3},
#  {'title': 'Duelul', 'year': 1981, 'count': 3},
#  {'title': 'The Cow', 'year': 1989, 'count': 3},
#  {'title': "Lilian's Story", 'year': 1996, 'count': 3},
#  {'title': 'Date Night', 'year': 2010, 'count': 3},
#  {'title': 'Upstream', 'year': 1927, 'count': 3},
#  {'title': 'Epic Movie', 'year': 2007, 'count': 3},
#  {'title': 'The Moth Diaries', 'year': 2011, 'count': 3},
#  {'title': 'The House by the Lake', 'year': 1976, 'count': 3},
#  {'title': 'Cairo Time', 'year': 2009, 'count': 3},
#  {'title': 'Roots', 'year': 1977, 'count': 3},
#  {'title': 'Kiss Kiss Bang Bang', 'year': 2005, 'count': 3},
#  {'title': 'Beauty Day', 'year': 2011, 'count': 3},
#  {'title': 'They Are All Dead', 'year': 2014, 'count': 3},
#  {'title': "Je t'aime je t'aime", 'year': 1968, 'count': 3},
#  {'title': 'Good Neighbors', 'year': 2010, 'count': 3},
#  {'title': 'Chronicle of Poor Lovers', 'year': 1954, 'count': 3},
#  {'title': 'When Good Ghouls Go Bad', 'year': 2001, 'count': 3},
#  {'title': 'Proteus', 'year': 2003, 'count': 3},
#  {'title': 'The Boys of St. Vincent', 'year': 1992, 'count': 3},
#  {'title': 'The Boxer', 'year': 1997, 'count': 3},
#  {'title': '45 Years', 'year': 2015, 'count': 3},
#  {'title': 'Bringing Ashley Home', 'year': 2011, 'count': 3},
#  {'title': 'High Spirits', 'year': 1988, 'count': 3},
#  {'title': 'Nas: Time Is Illmatic', 'year': 2014, 'count': 3},
#  {'title': 'American Courtesans', 'year': 2013, 'count': 3},
#  {'title': 'Slice', 'year': 2009, 'count': 3},
#  {'title': 'La buena nueva', 'year': 2008, 'count': 3},
#  {'title': 'Wah-Wah', 'year': 2005, 'count': 3},
#  {'title': 'Duck, You Sucker', 'year': 1971, 'count': 3},
#  {'title': 'Silent Running', 'year': 1972, 'count': 3},
#  {'title': 'Max Dugan Returns', 'year': 1983, 'count': 3},
#  {'title': 'Someone Like You', 'year': 2009, 'count': 3},
#  {'title': 'Stand Clear of the Closing Doors', 'year': 2013, 'count': 3},
#  {'title': "That's Entertainment, Part II", 'year': 1976, 'count': 3},
#  {'title': 'Chile, the Obstinate Memory', 'year': 1997, 'count': 3},
#  {'title': 'Batman: Gotham Knight', 'year': 2008, 'count': 3},
#  {'title': 'The Shaman', 'year': 2015, 'count': 3},
#  {'title': 'Bartok the Magnificent', 'year': 1999, 'count': 3},
#  {'title': 'The Motorcycle Diaries', 'year': 2004, 'count': 3},
#  {'title': 'Bride Wars', 'year': 2009, 'count': 3},
#  {'title': 'Pom Poko', 'year': 1994, 'count': 3},
#  {'title': 'The Cincinnati Kid', 'year': 1965, 'count': 3},
#  {'title': 'Cesar Chavez', 'year': 2014, 'count': 3},
#  {'title': 'Gangster Squad', 'year': 2013, 'count': 3},
#  {'title': 'Bleak Night', 'year': 2010, 'count': 3},
#  {'title': 'Return of the Living Dead III', 'year': 1993, 'count': 3},
#  {'title': 'The Promised Land', 'year': 1975, 'count': 3},
#  {'title': 'Federal Hill', 'year': 1994, 'count': 3},
#  {'title': 'Midnight FM', 'year': 2010, 'count': 3},
#  {'title': 'Peter and Vandy', 'year': 2009, 'count': 3},
#  {'title': '61*', 'year': 2001, 'count': 3},
#  {'title': 'The Mighty Ducks', 'year': 1992, 'count': 3},
#  {'title': 'Forgotten Silver', 'year': 1995, 'count': 3},
#  {'title': "Occupe-toi d'Amèlie..!", 'year': 1949, 'count': 3},
#  {'title': 'Lord of Darkness', 'year': 2012, 'count': 3},
#  {'title': 'The Apartment', 'year': 1960, 'count': 3},
#  {'title': 'The Dark House', 'year': 2009, 'count': 3},
#  {'title': 'Moebius', 'year': 1996, 'count': 3},
#  {'title': 'From Beyond', 'year': 1986, 'count': 3},
#  {'title': 'Great Migrations', 'year': 2010, 'count': 3},
#  {'title': 'Bionicle 3: Web of Shadows', 'year': 2005, 'count': 3},
#  {'title': 'Misconception', 'year': 2014, 'count': 3},
#  {'title': 'Black Robe', 'year': 1991, 'count': 3},
#  {'title': '3rd World Hero', 'year': 2000, 'count': 3},
#  {'title': 'Horror Express', 'year': 1972, 'count': 3},
#  {'title': 'Return to Paradise', 'year': 1998, 'count': 3},
#  {'title': 'Christmas in Connecticut', 'year': 1992, 'count': 3},
#  {'title': 'Taira Clan Saga', 'year': 1955, 'count': 3},
#  {'title': 'Hitler: The Rise of Evil', 'year': 2003, 'count': 3},
#  {'title': 'Black Cloud', 'year': 2004, 'count': 3},
#  {'title': 'Obitaemyy ostrov. Skhvatka', 'year': 2009, 'count': 3},
#  {'title': 'King & Country', 'year': 1964, 'count': 3},
#  {'title': 'Cube Zero', 'year': 2004, 'count': 3},
#  {'title': 'The Dark Side of Chocolate', 'year': 2010, 'count': 3},
#  {'title': 'The Valet', 'year': 2006, 'count': 3},
#  {'title': 'Never Tear Us Apart: The Untold Story of INXS',
#   'year': 2014,
#   'count': 3},
#  {'title': 'Scott Joplin', 'year': 1977, 'count': 3},
#  {'title': 'Metrobranding', 'year': 2010, 'count': 3},
#  {'title': 'Cold Feet', 'year': 1989, 'count': 3},
#  {'title': 'Exte: Hair Extensions', 'year': 2007, 'count': 3},
#  {'title': 'Nacho Libre', 'year': 2006, 'count': 3},
#  {'title': 'Drifting Clouds', 'year': 1996, 'count': 3},
#  {'title': 'Olympus Has Fallen', 'year': 2013, 'count': 3},
#  {'title': 'Twice in a Lifetime', 'year': 1985, 'count': 3},
#  {'title': 'Monster High: Friday Night Frights', 'year': 2013, 'count': 3},
#  {'title': 'Happenstance', 'year': 2000, 'count': 3},
#  {'title': 'The Saboteurs', 'year': 2015, 'count': 3},
#  {'title': 'Jesse Stone: Benefit of the Doubt', 'year': 2012, 'count': 3},
#  {'title': 'The Terminal', 'year': 2004, 'count': 3},
#  {'title': 'The Rising Place', 'year': 2001, 'count': 3},
#  {'title': 'Honey I Blew Up the Kid', 'year': 1992, 'count': 3},
#  {'title': 'A Wife Confesses', 'year': 1961, 'count': 3},
#  {'title': 'Bonhoeffer: Agent of Grace', 'year': 2000, 'count': 3},
#  {'title': 'Green Dragon', 'year': 2001, 'count': 3},
#  {'title': 'Overheard 2', 'year': 2011, 'count': 3},
#  {'title': 'Comeback Season', 'year': 2006, 'count': 3},
#  {'title': 'Yesterday, Today and Tomorrow', 'year': 1963, 'count': 3},
#  {'title': 'Amistad', 'year': 1997, 'count': 3},
#  {'title': 'Plastic', 'year': 2014, 'count': 3},
#  {'title': 'Mr. Average', 'year': 2006, 'count': 3},
#  {'title': 'Robin-B-Hood', 'year': 2006, 'count': 3},
#  {'title': "Everybody's Famous!", 'year': 2000, 'count': 3},
#  {'title': 'SAGA: Curse of the Shadow', 'year': 2013, 'count': 3},
#  {'title': 'Midnight Lace', 'year': 1960, 'count': 3},
#  {'title': 'Metalhead', 'year': 2013, 'count': 3},
#  {'title': 'The Unknown Woman', 'year': 2011, 'count': 3},
#  {'title': 'Palimpsest', 'year': 2006, 'count': 3},
#  {'title': 'A True Mob Story', 'year': 1998, 'count': 3},
#  {'title': 'Exists', 'year': 2014, 'count': 3},
#  {'title': 'Pink Saris', 'year': 2010, 'count': 3},
#  {'title': 'Footsteps in the Fog', 'year': 1955, 'count': 3},
#  {'title': 'Naming Number Two', 'year': 2006, 'count': 3},
#  {'title': 'I Am So Proud of You', 'year': 2008, 'count': 3},
#  {'title': "Betsy's Wedding", 'year': 1990, 'count': 3},
#  {'title': 'Macario', 'year': 1960, 'count': 3},
#  {'title': 'Ten Skies', 'year': 2004, 'count': 3},
#  {'title': 'Inherent Vice', 'year': 2014, 'count': 3},
#  {'title': "Jackie Chan's First Strike", 'year': 1996, 'count': 3},
#  {'title': 'Werner - Beinhart!', 'year': 1990, 'count': 3},
#  {'title': 'City of Men', 'year': 2007, 'count': 3},
#  {'title': 'Kabhi Khushi Kabhie Gham...', 'year': 2001, 'count': 2},
#  {'title': 'Mars et Avril', 'year': 2012, 'count': 2},
#  {'title': 'The Kite Runner', 'year': 2007, 'count': 2},
#  {'title': 'Boogie', 'year': 2009, 'count': 2},
#  {'title': 'Mentor', 'year': 2006, 'count': 2},
#  {'title': 'The Christmas Party', 'year': 2009, 'count': 2},
#  {'title': 'S#x Acts', 'year': 2012, 'count': 2},
#  {'title': 'Disclosure', 'year': 1994, 'count': 2},
#  {'title': 'El Estudiante', 'year': 2009, 'count': 2},
#  {'title': 'The Identity Theft of Mitch Mustain', 'year': 2013, 'count': 2},
#  {'title': '10 Minutes', 'year': 2013, 'count': 2},
#  {'title': 'Autohystoria', 'year': 2007, 'count': 2},
#  {'title': 'It Should Happen to You', 'year': 1954, 'count': 2},
#  {'title': 'White Noise 2: The Light', 'year': 2007, 'count': 2},
#  {'title': 'The Stepfather', 'year': 1987, 'count': 2},
#  {'title': 'Hit & Miss', 'year': '2012è', 'count': 2},
#  {'title': 'Big Game', 'year': 2014, 'count': 2},
#  {'title': 'The Wild and Wonderful Whites of West Virginia',
#   'year': 2009,
#   'count': 2},
#  {'title': 'The Earth Is a Sinful Song', 'year': 1973, 'count': 2},
#  {'title': 'The End of Suburbia: Oil Depletion and the Collapse of the American Dream',
#   'year': 2004,
#   'count': 2},
#  {'title': 'Motorway', 'year': 2012, 'count': 2},
#  {'title': 'The Raven', 'year': 2012, 'count': 2},
#  {'title': 'Temptation: Confessions of a Marriage Counselor',
#   'year': 2013,
#   'count': 2},
#  {'title': "Don't Be a Menace to South Central While Drinking Your Juice in the Hood",
#   'year': 1996,
#   'count': 2},
#  {'title': 'American Promise', 'year': 2013, 'count': 2},
#  {'title': 'Testament', 'year': 1983, 'count': 2},
#  {'title': 'The Untouchables', 'year': 1987, 'count': 2},
#  {'title': 'Tadpole', 'year': 2000, 'count': 2},
#  {'title': 'Eating', 'year': 1990, 'count': 2},
#  {'title': 'The Salton Sea', 'year': 2002, 'count': 2},
#  {'title': 'Like You Know It All', 'year': 2009, 'count': 2},
#  {'title': 'The Awakening', 'year': 2011, 'count': 2},
#  {'title': 'The Carey Treatment', 'year': 1972, 'count': 2},
#  {'title': 'Aalavandhan', 'year': 2001, 'count': 2},
#  {'title': "I Don't Kiss", 'year': 1991, 'count': 2},
#  {'title': 'The Grand Maneuver', 'year': 1955, 'count': 2},
#  {'title': 'Recoil', 'year': 2011, 'count': 2},
#  {'title': "Thou Gild'st the Even", 'year': 2013, 'count': 2},
#  {'title': 'Zamok', 'year': 1994, 'count': 2},
#  {'title': 'Cocktail', 'year': 1988, 'count': 2},
#  {'title': 'Passion of Love', 'year': 1981, 'count': 2},
#  {'title': 'The Kiss', 'year': 1988, 'count': 2},
#  {'title': 'Goyokin', 'year': 1969, 'count': 2},
#  {'title': 'A Brilliant Young Mind', 'year': 2014, 'count': 2},
#  {'title': 'Happiness', 'year': 1998, 'count': 2},
#  {'title': 'Iron Sky', 'year': 2012, 'count': 2},
#  {'title': 'EuroTrip', 'year': 2004, 'count': 2},
#  {'title': 'Super 8 Stories', 'year': 2001, 'count': 2},
#  {'title': 'Love in the Afternoon', 'year': 1957, 'count': 2},
#  {'title': 'The Theory of Everything', 'year': 2014, 'count': 2},
#  {'title': '009 Re: Cyborg', 'year': 2012, 'count': 2},
#  {'title': 'Red Riding Hood', 'year': 2011, 'count': 2},
#  {'title': 'The Returned', 'year': 2013, 'count': 2},
#  {'title': 'China Seas', 'year': 1935, 'count': 2},
#  {'title': 'Heaven and Earth', 'year': 1990, 'count': 2},
#  {'title': 'The 6th Day', 'year': 2000, 'count': 2},
#  {'title': 'Toad Road', 'year': 2012, 'count': 2},
#  {'title': 'Marine Battleground', 'year': 1963, 'count': 2},
#  {'title': 'Il minestrone', 'year': 1981, 'count': 2},
#  {'title': 'We Are Marshall', 'year': 2006, 'count': 2},
#  {'title': 'Eight Men Out', 'year': 1988, 'count': 2},
#  {'title': 'Pocahontas II: Journey to a New World', 'year': 1998, 'count': 2},
#  {'title': 'Slaughterhouse-Five', 'year': 1972, 'count': 2},
#  {'title': 'C.H.U.D.', 'year': 1984, 'count': 2},
#  {'title': 'Motherhood', 'year': 2009, 'count': 2},
#  {'title': 'Pathfinder', 'year': 2007, 'count': 2},
#  {'title': 'Dear Guest, When Will You Leave?', 'year': 2010, 'count': 2},
#  {'title': 'Barbie in a Mermaid Tale', 'year': 2010, 'count': 2},
#  {'title': 'The Names of Love', 'year': 2010, 'count': 2},
#  {'title': 'Pieces of Dreams', 'year': 1970, 'count': 2},
#  {'title': 'Raincoat', 'year': 2004, 'count': 2},
#  {'title': 'Crazy', 'year': 2000, 'count': 2},
#  {'title': 'Inside Job', 'year': 2010, 'count': 2},
#  {'title': 'The Girl and Death', 'year': 2012, 'count': 2},
#  {'title': 'Downeast', 'year': 2012, 'count': 2},
#  {'title': 'Face/Off', 'year': 1997, 'count': 2},
#  {'title': 'The Forgotten', 'year': 2004, 'count': 2},
#  {'title': 'Day & Night', 'year': 2010, 'count': 2},
#  {'title': 'Bewitched', 'year': 2005, 'count': 2},
#  {'title': 'The Bank Job', 'year': 2008, 'count': 2},
#  {'title': 'Little Hope Was Arson', 'year': 2013, 'count': 2},
#  {'title': 'Looking for Eric', 'year': 2009, 'count': 2},
#  {'title': 'Speed 2: Cruise Control', 'year': 1997, 'count': 2},
#  {'title': 'Bad Words', 'year': 2013, 'count': 2},
#  {'title': 'Dance, Girl, Dance', 'year': 1940, 'count': 2},
#  {'title': 'Frenzy', 'year': 1972, 'count': 2},
#  {'title': "Marie's Story", 'year': 2014, 'count': 2},
#  {'title': "Nobody's Daughter Haewon", 'year': 2013, 'count': 2},
#  {'title': 'Call Me Lucky', 'year': 2015, 'count': 2},
#  {'title': 'Attack', 'year': 1956, 'count': 2},
#  {'title': 'Pop Skull', 'year': 2007, 'count': 2},
#  {'title': 'The Cruise', 'year': 1998, 'count': 2},
#  {'title': 'The Homesman', 'year': 2014, 'count': 2},
#  {'title': 'The Lost Bladesman', 'year': 2011, 'count': 2},
#  {'title': 'The Terror Live', 'year': 2013, 'count': 2},
#  {'title': 'B-Movie: Lust & Sound in West-Berlin 1979-1989',
#   'year': 2015,
#   'count': 2},
#  {'title': 'Cubeè: Hypercube', 'year': 2002, 'count': 2},
#  {'title': 'Le poulpe', 'year': 1998, 'count': 2},
#  {'title': 'Smashed', 'year': 2012, 'count': 2},
#  {'title': 'Patlabor 2: The Movie', 'year': 1993, 'count': 2},
#  {'title': 'Bridget Jones: The Edge of Reason', 'year': 2004, 'count': 2},
#  {'title': 'The Dentist', 'year': 1996, 'count': 2},
#  {'title': 'Leave to Remain', 'year': 2013, 'count': 2},
#  {'title': 'Beautiful', 'year': 2009, 'count': 2},
#  {'title': 'Galaxy Express 999', 'year': 1979, 'count': 2},
#  {'title': 'WarGames: The Dead Code', 'year': 2008, 'count': 2},
#  {'title': 'Family Secrets', 'year': 2001, 'count': 2},
#  {'title': 'The Best Exotic Marigold Hotel', 'year': 2011, 'count': 2},
#  {'title': 'Cattle Annie and Little Britches', 'year': 1981, 'count': 2},
#  {'title': 'Joseph and the Amazing Technicolor Dreamcoat',
#   'year': 1999,
#   'count': 2},
#  {'title': 'National Velvet', 'year': 1944, 'count': 2},
#  {'title': 'Der letzte schène Herbsttag', 'year': 2010, 'count': 2},
#  {'title': 'Flash of Genius', 'year': 2008, 'count': 2},
#  {'title': 'Beautiful Girls', 'year': 1996, 'count': 2},
#  {'title': 'Asterix and the Vikings', 'year': 2006, 'count': 2},
#  {'title': 'Justice League: Doom', 'year': 2012, 'count': 2},
#  {'title': 'Above and Below', 'year': 2015, 'count': 2},
#  {'title': 'The Pearl Button', 'year': 2015, 'count': 2},
#  {'title': 'Richard Pryor: Omit the Logic', 'year': 2013, 'count': 2},
#  {'title': 'Genius Within: The Inner Life of Glenn Gould',
#   'year': 2009,
#   'count': 2},
#  {'title': 'Downfall', 'year': 2004, 'count': 2},
#  {'title': 'Beavis and Butt-Head Do America', 'year': 1996, 'count': 2},
#  {'title': 'The House of Small Cubes', 'year': 2008, 'count': 2},
#  {'title': 'Just Eat It: A Food Waste Story', 'year': 2014, 'count': 2},
#  {'title': 'Messi', 'year': 2014, 'count': 2},
#  {'title': 'The Truce', 'year': 1997, 'count': 2},
#  {'title': 'The Eagle', 'year': 2011, 'count': 2},
#  {'title': 'Anna M.', 'year': 2007, 'count': 2},
#  {'title': "Refugee All Stars, Sierra Leone's", 'year': 2005, 'count': 2},
#  {'title': 'Christmas in Boston', 'year': 2005, 'count': 2},
#  {'title': 'Brigham City', 'year': 2001, 'count': 2},
#  {'title': 'Kiss Me in the Rain', 'year': 1999, 'count': 2},
#  {'title': 'What About Bob?', 'year': 1991, 'count': 2},
#  {'title': 'Flashdance', 'year': 1983, 'count': 2},
#  {'title': 'The Noble Family', 'year': 2013, 'count': 2},
#  {'title': 'So Normal', 'year': 2003, 'count': 2},
#  {'title': 'The New Adventures of Pippi Longstocking',
#   'year': 1988,
#   'count': 2},
#  {'title': 'Chaos', 'year': 2001, 'count': 2},
#  {'title': 'Blue Caprice', 'year': 2013, 'count': 2},
#  {'title': 'Alien Nation', 'year': 1988, 'count': 2},
#  {'title': 'Thor', 'year': 2011, 'count': 2},
#  {'title': 'Best Laid Plans', 'year': 1999, 'count': 2},
#  {'title': 'Fort Tilden', 'year': 2014, 'count': 2},
#  {'title': 'An Englishman in New York', 'year': 2009, 'count': 2},
#  {'title': 'The Unfaithful Wife', 'year': 1969, 'count': 2},
#  {'title': 'My Sweet Little Village', 'year': 1985, 'count': 2},
#  {'title': "The Butterfly's Dream", 'year': 2013, 'count': 2},
#  {'title': 'Year One', 'year': 2009, 'count': 2},
#  {'title': 'The Last of the High Kings', 'year': 1996, 'count': 2},
#  {'title': 'Chaotic Ana', 'year': 2007, 'count': 2},
#  {'title': 'Boys', 'year': 1977, 'count': 2},
#  {'title': 'Miss Minoes', 'year': 2001, 'count': 2},
#  {'title': 'The Road to Love', 'year': 2001, 'count': 2},
#  {'title': "Say It Isn't So", 'year': 2001, 'count': 2},
#  {'title': 'Soft Shell Man', 'year': 2001, 'count': 2},
#  {'title': 'Triumph Over Violence', 'year': 1965, 'count': 2},
#  {'title': 'Quo Vadis, Baby?', 'year': 2005, 'count': 2},
#  {'title': 'Godzilla 1985', 'year': 1984, 'count': 2},
#  {'title': 'Whisper If I Forget', 'year': 2014, 'count': 2},
#  {'title': 'Little Soldier', 'year': 2008, 'count': 2},
#  {'title': 'The Time Machine', 'year': 2002, 'count': 2},
#  {'title': "The Band's Visit", 'year': 2007, 'count': 2},
#  {'title': 'Monsters vs Aliens: Mutant Pumpkins from Outer Space',
#   'year': 2009,
#   'count': 2},
#  {'title': 'Mrs Dalloway', 'year': 1997, 'count': 2},
#  {'title': 'Detention', 'year': 2003, 'count': 2},
#  {'title': 'Night Owls', 'year': 2015, 'count': 2},
#  {'title': 'Jack Brooks: Monster Slayer', 'year': 2007, 'count': 2},
#  {'title': 'Local Color', 'year': 2006, 'count': 2},
#  {'title': 'BloodRayne', 'year': 2005, 'count': 2},
#  {'title': 'Ghosts of the Abyss', 'year': 2003, 'count': 2},
#  {'title': 'Bonjour Monsieur Shlomi', 'year': 2003, 'count': 2},
#  {'title': 'Urbania', 'year': 2000, 'count': 2},
#  {'title': 'PiraMMMida', 'year': 2011, 'count': 2},
#  {'title': 'Somewhere Under the Broad Sky', 'year': 1954, 'count': 2},
#  {'title': 'The Last Sentence', 'year': 2012, 'count': 2},
#  {'title': 'Spice World', 'year': 1997, 'count': 2},
#  {'title': 'Precious', 'year': 2009, 'count': 2},
#  {'title': 'La strega in amore', 'year': 1966, 'count': 2},
#  {'title': 'The Things of Life', 'year': 1970, 'count': 2},
#  {'title': 'Heaven on Earth', 'year': 2006, 'count': 2},
#  {'title': 'Nine Months', 'year': 1995, 'count': 2},
#  {'title': 'The Quiet Family', 'year': 1998, 'count': 2},
#  {'title': 'Approaching the Elephant', 'year': 2014, 'count': 2},
#  {'title': 'The Castle', 'year': 1997, 'count': 2},
#  {'title': 'The Painting', 'year': 2011, 'count': 2},
#  {'title': 'Carrie', 'year': 2013, 'count': 2},
#  {'title': 'Black Souls', 'year': 2014, 'count': 2},
#  {'title': 'Joy Ride', 'year': 2001, 'count': 2},
#  {'title': 'The Amati Girls', 'year': 2000, 'count': 2},
#  {'title': 'The Bridesmaid', 'year': 2004, 'count': 2},
#  {'title': 'Grizzly Falls', 'year': 1999, 'count': 2},
#  {'title': 'Destiny', 'year': 2006, 'count': 2},
#  {'title': 'Between the Lines', 'year': 1977, 'count': 2},
#  {'title': 'Goon', 'year': 2011, 'count': 2},
#  {'title': 'Shock Head Soul', 'year': 2011, 'count': 2},
#  {'title': 'The Elusive Corporal', 'year': 1962, 'count': 2},
#  {'title': 'Marnie', 'year': 1964, 'count': 2},
#  {'title': 'Visitor Q', 'year': 2001, 'count': 2},
#  {'title': 'It Rains in My Village', 'year': 1968, 'count': 2},
#  {'title': 'Archangel', 'year': 1990, 'count': 2},
#  {'title': 'Fatso', 'year': 1980, 'count': 2},
#  {'title': 'Shakthi: The Power', 'year': 2002, 'count': 2},
#  {'title': 'Locke', 'year': 2013, 'count': 2},
#  {'title': 'The Mugger', 'year': 2007, 'count': 2},
#  {'title': 'Bagdad Cafe', 'year': 1987, 'count': 2},
#  {'title': 'The Jew in the Lotus', 'year': 1998, 'count': 2},
#  {'title': 'The Big Lebowski', 'year': 1998, 'count': 2},
#  {'title': "A Hard Day's Night", 'year': 1964, 'count': 2},
#  {'title': '3è kèlter', 'year': 2005, 'count': 2},
#  {'title': 'Ju-on: The Grudge', 'year': 2002, 'count': 2},
#  {'title': 'Bad Eggs', 'year': 2003, 'count': 2},
#  {'title': 'Raising Victor Vargas', 'year': 2002, 'count': 2},
#  {'title': 'Three Colors: Blue', 'year': 1993, 'count': 2},
#  {'title': 'In the Grayscale', 'year': 2015, 'count': 2},
#  {'title': 'The Brotherhood', 'year': 1968, 'count': 2},
#  {'title': '600 Millas', 'year': 2015, 'count': 2},
#  {'title': 'Thirty Two Short Films About Glenn Gould',
#   'year': 1993,
#   'count': 2},
#  {'title': 'Pulse', 'year': 2001, 'count': 2},
#  {'title': 'Schoolgirls Growing Up', 'year': 1972, 'count': 2},
#  {'title': 'Tamala 2010: A Punk Cat in Space', 'year': 2002, 'count': 2},
#  {'title': 'Thirst', 'year': 2010, 'count': 2},
#  {'title': 'Mr. Baseball', 'year': 1992, 'count': 2},
#  {'title': 'God Is Brazilian', 'year': 2003, 'count': 2},
#  {'title': 'The Incident', 'year': 2014, 'count': 2},
#  {'title': 'Spontaneous Combustion', 'year': 1990, 'count': 2},
#  {'title': 'Addicted to Love', 'year': 1997, 'count': 2},
#  {'title': 'Little Children', 'year': 2006, 'count': 2},
#  {'title': 'Orlando', 'year': 1992, 'count': 2},
#  {'title': 'Brother', 'year': 2000, 'count': 2},
#  {'title': 'The Union', 'year': 2011, 'count': 2},
#  {'title': 'The Professor and His Beloved Equation', 'year': 2006, 'count': 2},
#  {'title': 'All the Rage', 'year': 1999, 'count': 2},
#  {'title': 'Rouge', 'year': 1987, 'count': 2},
#  {'title': "His Wife's Diary", 'year': 2000, 'count': 2},
#  {'title': 'Truly Human', 'year': 2001, 'count': 2},
#  {'title': 'Yves Saint Laurent', 'year': 2014, 'count': 2},
#  {'title': 'Princess Arete', 'year': 2001, 'count': 2},
#  {'title': 'John Adams', 'year': 2008, 'count': 2},
#  {'title': 'The Blue Umbrella', 'year': 2013, 'count': 2},
#  {'title': 'Stand and Deliver', 'year': 1988, 'count': 2},
#  {'title': 'Bestseller', 'year': 2010, 'count': 2},
#  {'title': 'Sebbe', 'year': 2010, 'count': 2},
#  {'title': 'Robot Jox', 'year': 1989, 'count': 2},
#  {'title': 'Utomlyonnye solntsem 2: Predstoyanie', 'year': 2010, 'count': 2},
#  {'title': 'Miss Julie', 'year': 1999, 'count': 2},
#  {'title': 'Decency', 'year': 2013, 'count': 2},
#  {'title': 'Sorry for the Disturbance', 'year': 2008, 'count': 2},
#  {'title': 'Like the Wind', 'year': 2013, 'count': 2},
#  {'title': 'Flower & Garnet', 'year': 2002, 'count': 2},
#  {'title': 'Gidget', 'year': 1959, 'count': 2},
#  {'title': 'Oklahoma Crude', 'year': 1973, 'count': 2},
#  {'title': "Girls Can't Swim", 'year': 2000, 'count': 2},
#  {'title': 'Princess Mononoke', 'year': 1997, 'count': 2},
#  {'title': 'Freeway', 'year': 1996, 'count': 2},
#  {'title': '4 Minutes', 'year': 2006, 'count': 2},
#  {'title': 'Asfalttilampaat', 'year': 1968, 'count': 2},
#  {'title': 'Mermaid Chronicles Part 1: She Creature',
#   'year': 2001,
#   'count': 2},
#  {'title': 'Baggage Claim', 'year': 2013, 'count': 2},
#  {'title': "We Don't Live Here Anymore", 'year': 2004, 'count': 2},
#  {'title': 'China Blue', 'year': 2005, 'count': 2},
#  {'title': 'Hatchet II', 'year': 2010, 'count': 2},
#  {'title': "Charlotte's Web", 'year': 2006, 'count': 2},
#  {'title': 'Starter for 10', 'year': 2006, 'count': 2},
#  {'title': 'Interview', 'year': 2007, 'count': 2},
#  {'title': 'Tab Hunter Confidential', 'year': 2015, 'count': 2},
#  {'title': "A Birder's Guide to Everything", 'year': 2013, 'count': 2},
#  {'title': 'Lèon: The Professional', 'year': 1994, 'count': 2},
#  {'title': 'Life and Nothing But', 'year': 1989, 'count': 2},
#  {'title': 'StarStruck', 'year': 2010, 'count': 2},
#  {'title': 'La vendedora de rosas', 'year': 1998, 'count': 2},
#  {'title': 'Blackrock', 'year': 1997, 'count': 2},
#  {'title': 'Police Story', 'year': 1985, 'count': 2},
#  {'title': 'Catfish in Black Bean Sauce', 'year': 1999, 'count': 2},
#  {'title': "You Can't Take It With You", 'year': 1938, 'count': 2},
#  {'title': "Love's Enduring Promise", 'year': 2004, 'count': 2},
#  {'title': 'My Tomorrow', 'year': 2011, 'count': 2},
#  {'title': 'Om Shanti Om', 'year': 2007, 'count': 2},
#  {'title': 'Sweetie', 'year': 1989, 'count': 2},
#  {'title': 'Murder in Greenwich', 'year': 2002, 'count': 2},
#  {'title': 'The Black Stallion Returns', 'year': 1983, 'count': 2},
#  {'title': 'Heaven', 'year': 1998, 'count': 2},
#  {'title': 'Crazy for Christmas', 'year': 2005, 'count': 2},
#  {'title': 'Percy Jackson: Sea of Monsters', 'year': 2013, 'count': 2},
#  {'title': 'Boy s tenyu', 'year': 2005, 'count': 2},
#  {'title': 'Wild Flowers', 'year': 2000, 'count': 2},
#  {'title': 'Scent of a Woman', 'year': 1992, 'count': 2},
#  {'title': 'Shiloh', 'year': 1996, 'count': 2},
#  {'title': 'Yogi Bear', 'year': 2010, 'count': 2},
#  {'title': 'Hacking Democracy', 'year': 2006, 'count': 2},
#  {'title': 'The Munekata Sisters', 'year': 1950, 'count': 2},
#  {'title': 'Madeline', 'year': 1998, 'count': 2},
#  {'title': 'Kacheli', 'year': 2008, 'count': 2},
#  {'title': 'Nowhere Boy', 'year': 2009, 'count': 2},
#  {'title': 'Ivy', 'year': 2015, 'count': 2},
#  {'title': 'Goodnight, Mister Tom', 'year': 1998, 'count': 2},
#  {'title': 'Deadly Voyage', 'year': 1996, 'count': 2},
#  {'title': 'The Adventure of Faustus Bidgood', 'year': 1986, 'count': 2},
#  {'title': 'The Caretakers', 'year': 1963, 'count': 2},
#  {'title': "Let's Be Cops", 'year': 2014, 'count': 2},
#  {'title': 'Victory Through Air Power', 'year': 1943, 'count': 2},
#  {'title': 'An American Girl Adventure', 'year': 2005, 'count': 2},
#  {'title': 'The Siege', 'year': 1998, 'count': 2},
#  {'title': 'Two Weeks Notice', 'year': 2002, 'count': 2},
#  {'title': 'Lucky Luke and the Daltons', 'year': 2004, 'count': 2},
#  {'title': 'Tooth Fairy', 'year': 2010, 'count': 2},
#  {'title': 'The Naked and the Dead', 'year': 1958, 'count': 2},
#  {'title': 'Mystery Road', 'year': 2013, 'count': 2},
#  {'title': 'Destino', 'year': 2003, 'count': 2},
#  {'title': 'Lucky Break', 'year': 2001, 'count': 2},
#  {'title': 'Noce blanche', 'year': 1989, 'count': 2},
#  {'title': 'Three', 'year': 1965, 'count': 2},
#  {'title': 'Savage', 'year': 2011, 'count': 2},
#  {'title': 'Barocco', 'year': 1976, 'count': 2},
#  {'title': "Winter's Tale", 'year': 2014, 'count': 2},
#  {'title': 'The Witches of Eastwick', 'year': 1987, 'count': 2},
#  {'title': 'Corpse Bride', 'year': 2005, 'count': 2},
#  {'title': 'The Bandit', 'year': 1946, 'count': 2},
#  {'title': 'What the Deaf Man Heard', 'year': 1997, 'count': 2},
#  {'title': 'Midnight Express', 'year': 1978, 'count': 2},
#  {'title': 'Lola', 'year': 1981, 'count': 2},
#  {'title': 'Mother Dao, the Turtlelike', 'year': 1995, 'count': 2},
#  {'title': 'A House Built on Water', 'year': 2003, 'count': 2},
#  {'title': 'Lakota Woman: Siege at Wounded Knee', 'year': 1994, 'count': 2},
#  {'title': 'Himizu', 'year': 2011, 'count': 2},
#  {'title': 'Teenage', 'year': 2013, 'count': 2},
#  {'title': "Mary Shelley's Frankenstein", 'year': 1994, 'count': 2},
#  {'title': 'The Princess and the Warrior', 'year': 2000, 'count': 2},
#  {'title': 'The Children', 'year': 2008, 'count': 2},
#  {'title': 'Mother and Child', 'year': 2009, 'count': 2},
#  {'title': 'Isadora', 'year': 1968, 'count': 2},
#  {'title': 'Tell Me a Riddle', 'year': 1980, 'count': 2},
#  {'title': 'No Turning Back', 'year': 2001, 'count': 2},
#  {'title': "A Stranger's Heart", 'year': 2007, 'count': 2},
#  {'title': 'Road House', 'year': 1948, 'count': 2},
#  {'title': 'Blind Date', 'year': 1987, 'count': 2},
#  {'title': 'The Stranger', 'year': 1991, 'count': 2},
#  {'title': 'Run, Simon, Run', 'year': 1970, 'count': 2},
#  {'title': 'Cruel & Unusual', 'year': 2014, 'count': 2},
#  {'title': 'The Medallion', 'year': 2003, 'count': 2},
#  {'title': 'Jeanne la Pucelle II - Les prisons', 'year': 1994, 'count': 2},
#  {'title': 'Year of the Devil', 'year': 2002, 'count': 2},
#  {'title': 'Newsfront', 'year': 1978, 'count': 2},
#  {'title': 'Species III', 'year': 2004, 'count': 2},
#  {'title': 'La escopeta nacional', 'year': 1978, 'count': 2},
#  {'title': 'The Settlement', 'year': 2002, 'count': 2},
#  {'title': 'The Nude Bomb', 'year': 1980, 'count': 2},
#  {'title': 'Priceless', 'year': 2006, 'count': 2},
#  {'title': 'Bes Sehir', 'year': 2010, 'count': 2},
#  {'title': 'A Nightmare on Elm Street', 'year': 2010, 'count': 2},
#  {'title': 'Daybreakers', 'year': 2009, 'count': 2},
#  {'title': 'The Russian Novel', 'year': 2012, 'count': 2},
#  {'title': 'Lyubov 2 Morkov', 'year': 2008, 'count': 2},
#  {'title': 'Breathing Room', 'year': 1996, 'count': 2},
#  {'title': 'Dreamcatcher', 'year': 2015, 'count': 2},
#  {'title': 'The Kentuckian', 'year': 1955, 'count': 2},
#  {'title': 'Verlengd weekend', 'year': 2005, 'count': 2},
#  {'title': 'Appleseed Saga: Ex Machina', 'year': 2007, 'count': 2},
#  {'title': 'Still Alice', 'year': 2014, 'count': 2},
#  {'title': 'The Great Santini', 'year': 1979, 'count': 2},
#  {'title': 'To Rome with Love', 'year': 2012, 'count': 2},
#  {'title': 'Prison Terminal: The Last Days of Private Jack Hall',
#   'year': 2013,
#   'count': 2},
#  {'title': 'Warriors of Virtue', 'year': 1997, 'count': 2},
#  {'title': 'April and the Extraordinary World', 'year': 2015, 'count': 2},
#  {'title': 'The Love Guru', 'year': 2008, 'count': 2},
#  {'title': 'The Greggs', 'year': 2014, 'count': 2},
#  {'title': 'Two for the Seesaw', 'year': 1962, 'count': 2},
#  {'title': 'Reversal of Fortune', 'year': 1990, 'count': 2},
#  {'title': 'Redacted', 'year': 2007, 'count': 2},
#  {'title': 'Mondo', 'year': 1995, 'count': 2},
#  {'title': 'How Do You Know', 'year': 2010, 'count': 2},
#  {'title': 'Homer and Eddie', 'year': 1989, 'count': 2},
#  {'title': 'Thirteen', 'year': 2003, 'count': 2},
#  {'title': 'Cheap Smokes', 'year': 2000, 'count': 2},
#  {'title': '20,000 Days on Earth', 'year': 2014, 'count': 2},
#  {'title': 'Venus', 'year': 2006, 'count': 2},
#  {'title': 'Class Action', 'year': 1991, 'count': 2},
#  {'title': 'Swimming with Sharks', 'year': 1994, 'count': 2},
#  {'title': 'Radio', 'year': 2003, 'count': 2},
#  {'title': 'Unforgiven', 'year': 1992, 'count': 2},
#  {'title': 'Sue', 'year': 1997, 'count': 2},
#  {'title': 'Hotel Swooni', 'year': 2011, 'count': 2},
#  {'title': 'Munich', 'year': 2005, 'count': 2},
#  {'title': 'Chan Is Missing', 'year': 1982, 'count': 2},
#  {'title': 'Rated X', 'year': 2000, 'count': 2},
#  {'title': 'A Slipping-Down Life', 'year': 1999, 'count': 2},
#  {'title': 'Min sèsters bèrn i Afrika', 'year': 2013, 'count': 2},
#  {'title': 'Beaches', 'year': 1988, 'count': 2},
#  {'title': "Lord's Lantern in Budapest", 'year': 1999, 'count': 2},
#  {'title': 'Semi-Pro', 'year': 2008, 'count': 2},
#  {'title': 'Bangkok Hilton', 'year': 1989, 'count': 2},
#  {'title': 'R.S.V.P.', 'year': 2002, 'count': 2},
#  {'title': 'Kisaragi', 'year': 2007, 'count': 2},
#  {'title': 'Sex, Party and Lies', 'year': 2009, 'count': 2},
#  {'title': 'Villegas', 'year': 2012, 'count': 2},
#  {'title': 'One Fine Day', 'year': 1996, 'count': 2},
#  {'title': 'The Signal', 'year': 2007, 'count': 2},
#  {'title': '40 Pounds of Trouble', 'year': 1962, 'count': 2},
#  {'title': 'The Delta Force', 'year': 1986, 'count': 2},
#  {'title': 'Will Success Spoil Rock Hunter?', 'year': 1957, 'count': 2},
#  {'title': 'Possession', 'year': 1981, 'count': 2},
#  {'title': 'Arthur Christmas', 'year': 2011, 'count': 2},
#  {'title': 'Eloise at the Plaza', 'year': 2003, 'count': 2},
#  {'title': 'Muppets Most Wanted', 'year': 2014, 'count': 2},
#  {'title': 'The Endurance', 'year': 2000, 'count': 2},
#  {'title': 'A Sunday in Kigali', 'year': 2006, 'count': 2},
#  {'title': 'Slap Shot', 'year': 1977, 'count': 2},
#  {'title': 'Torque', 'year': 2004, 'count': 2},
#  {'title': 'An Injury to One', 'year': 2002, 'count': 2},
#  {'title': 'Adult World', 'year': 2013, 'count': 2},
#  {'title': 'Don', 'year': 1978, 'count': 2},
#  {'title': 'Hardcore', 'year': 2004, 'count': 2},
#  {'title': 'White Bird in a Blizzard', 'year': 2014, 'count': 2},
#  {'title': 'Charly', 'year': 1968, 'count': 2},
#  {'title': 'Time Stood Still', 'year': 1959, 'count': 2},
#  {'title': 'Bitva za Sevastopol', 'year': 2015, 'count': 2},
#  {'title': 'Hammer & Tickle', 'year': 2006, 'count': 2},
#  {'title': 'Bright Lights, Big City', 'year': 1988, 'count': 2},
#  {'title': 'Broken Lullaby', 'year': 1932, 'count': 2},
#  {'title': 'Mississippi Masala', 'year': 1991, 'count': 2},
#  {'title': "Jacob's Ladder", 'year': 1990, 'count': 2},
#  {'title': "Porky's", 'year': 1981, 'count': 2},
#  {'title': 'Hellraiser: Inferno', 'year': 2000, 'count': 2},
#  {'title': 'Cannibal Girls', 'year': 1973, 'count': 2},
#  {'title': 'Hiroshima', 'year': 2005, 'count': 2},
#  {'title': 'Powder', 'year': 1995, 'count': 2},
#  {'title': 'Sabotage', 'year': 2014, 'count': 2},
#  {'title': 'Nomad: The Warrior', 'year': 2005, 'count': 2},
#  {'title': 'Someone to Watch Over Me', 'year': 1987, 'count': 2},
#  {'title': "We Don't Care About Music Anyway", 'year': 2009, 'count': 2},
#  {'title': 'Unbreakable', 'year': 2000, 'count': 2},
#  {'title': "Devil's Pass", 'year': 2013, 'count': 2},
#  {'title': 'Hawaii, Oslo', 'year': 2004, 'count': 2},
#  {'title': 'Poppy Shakespeare', 'year': 2008, 'count': 2},
#  {'title': "Fanie Fourie's Lobola", 'year': 2013, 'count': 2},
#  {'title': "Varian's War", 'year': 2001, 'count': 2},
#  {'title': 'Trial', 'year': 1955, 'count': 2},
#  {'title': 'Schtonk!', 'year': 1992, 'count': 2},
#  {'title': 'Dead Presidents', 'year': 1995, 'count': 2},
#  {'title': "I'm the One You Want", 'year': 2014, 'count': 2},
#  {'title': 'Stavisky...', 'year': 1974, 'count': 2},
#  {'title': 'Den ofrivillige golfaren', 'year': 1991, 'count': 2},
#  {'title': 'Action Jackson', 'year': 1988, 'count': 2},
#  {'title': 'Ruhr', 'year': 2009, 'count': 2},
#  {'title': "Marilyn Hotchkiss' Ballroom Dancing & Charm School",
#   'year': 2005,
#   'count': 2},
#  {'title': 'Wandering Sagittarius', 'year': 1993, 'count': 2},
#  {'title': 'Knallharte Jungs', 'year': 2002, 'count': 2},
#  {'title': 'Corporate', 'year': 2006, 'count': 2},
#  {'title': 'Dreamscape', 'year': 1984, 'count': 2},
#  {'title': "What Doesn't Kill You", 'year': 2008, 'count': 2},
#  {'title': 'Last Days', 'year': 2005, 'count': 2},
#  {'title': 'Kristin Lavransdatter', 'year': 1995, 'count': 2},
#  {'title': 'Ex Machina', 'year': 2015, 'count': 2},
#  {'title': 'Remember My Name', 'year': 1978, 'count': 2},
#  {'title': 'Toolbox Murders', 'year': 2004, 'count': 2},
#  {'title': 'The Ogre of Athens', 'year': 1956, 'count': 2},
#  {'title': 'Bugsy Malone', 'year': 1976, 'count': 2},
#  {'title': 'Cheetah', 'year': 1989, 'count': 2},
#  {'title': 'Suburban Gothic', 'year': 2014, 'count': 2},
#  {'title': 'Men Vs Women', 'year': 2010, 'count': 2},
#  {'title': 'Kafka', 'year': 1991, 'count': 2},
#  {'title': 'The Left Handed Gun', 'year': 1958, 'count': 2},
#  {'title': 'The End of the Affair', 'year': 1955, 'count': 2},
#  {'title': 'The Bachelor', 'year': 1955, 'count': 2},
#  {'title': "Wood & Stock: Sexo, Orègano e Rock'n'Roll",
#   'year': 2006,
#   'count': 2},
#  {'title': 'Wedding Chest', 'year': 2005, 'count': 2},
#  {'title': 'Stopped on Track', 'year': 2011, 'count': 2},
#  {'title': 'Niezwykla podrèz Baltazara Kobera', 'year': 1988, 'count': 2},
#  {'title': 'Titanica', 'year': 1995, 'count': 2},
#  {'title': 'Head in the Clouds', 'year': 2004, 'count': 2},
#  {'title': 'Shotgun Stories', 'year': 2007, 'count': 2},
#  {'title': 'My Girl', 'year': 2003, 'count': 2},
#  {'title': 'Room for One More', 'year': 1952, 'count': 2},
#  {'title': 'Battlefield Earth', 'year': 2000, 'count': 2},
#  {'title': 'Overheard', 'year': 2009, 'count': 2},
#  {'title': 'The Bridge of San Luis Rey', 'year': 2004, 'count': 2},
#  {'title': 'Rich Kids', 'year': 1979, 'count': 2},
#  {'title': 'Brigadoon', 'year': 1954, 'count': 2},
#  {'title': 'Houdini', 'year': 2014, 'count': 2},
#  {'title': 'Concerning Violence', 'year': 2014, 'count': 2},
#  {'title': 'We Are Young. We Are Strong.', 'year': 2014, 'count': 2},
#  {'title': 'The Vanishing Prairie', 'year': 1954, 'count': 2},
#  {'title': 'The Moon in the Gutter', 'year': 1983, 'count': 2},
#  {'title': 'Stop! Or My Mom Will Shoot', 'year': 1992, 'count': 2},
#  {'title': 'The Incident', 'year': 1967, 'count': 2},
#  {'title': "Bill Maher... But I'm Not Wrong", 'year': 2010, 'count': 2},
#  {'title': 'Yankee Doodle Dandy', 'year': 1942, 'count': 2},
#  {'title': 'Thorne: Sleepyhead', 'year': 2010, 'count': 2},
#  {'title': 'The Book of Life', 'year': 2014, 'count': 2},
#  {'title': 'Shadows', 'year': 2007, 'count': 2},
#  {'title': 'Juno', 'year': 2007, 'count': 2},
#  {'title': 'Monica Z', 'year': 2013, 'count': 2},
#  {'title': 'Moonrise Kingdom', 'year': 2012, 'count': 2},
#  {'title': 'The Toxic Avenger Part III: The Last Temptation of Toxie',
#   'year': 1989,
#   'count': 2},
#  {'title': 'Butterfly', 'year': 1999, 'count': 2},
#  {'title': 'Vitus', 'year': 2006, 'count': 2},
#  {'title': 'Nightcrawler', 'year': 2014, 'count': 2},
#  {'title': 'The Prisoner', 'year': 1955, 'count': 2},
#  {'title': 'Blood River', 'year': 1967, 'count': 2},
#  {'title': 'Ride Along', 'year': 2014, 'count': 2},
#  {'title': 'Step Up', 'year': 2006, 'count': 2},
#  {'title': 'The Whole Ten Yards', 'year': 2004, 'count': 2},
#  {'title': 'The Art of War', 'year': 2000, 'count': 2},
#  {'title': 'Pitkè kuuma kesè', 'year': 1999, 'count': 2},
#  {'title': 'Solomon Kane', 'year': 2009, 'count': 2},
#  {'title': 'The Rescuers', 'year': 1977, 'count': 2},
#  {'title': 'Continental, un film sans fusil', 'year': 2007, 'count': 2},
#  {'title': "Pao's Story", 'year': 2006, 'count': 2},
#  {'title': 'Hell and Back Again', 'year': 2011, 'count': 2},
#  {'title': 'Khaleja', 'year': 2010, 'count': 2},
#  {'title': 'The Clone Returns Home', 'year': 2008, 'count': 2},
#  {'title': 'Up Close & Personal', 'year': 1996, 'count': 2},
#  {'title': 'Somewhere', 'year': 2010, 'count': 2},
#  {'title': 'Middle Sexes: Redefining He and She', 'year': 2005, 'count': 2},
#  {'title': 'Great Balls of Fire!', 'year': 1989, 'count': 2},
#  {'title': 'Look', 'year': 2007, 'count': 2},
#  {'title': 'Elliot Loves', 'year': 2012, 'count': 2},
#  {'title': 'Come Undone', 'year': 2000, 'count': 2},
#  {'title': 'Gold', 'year': 1974, 'count': 2},
#  {'title': 'Tetro', 'year': 2009, 'count': 2},
#  {'title': 'Xala', 'year': 1975, 'count': 2},
#  {'title': 'Saving Face', 'year': 2004, 'count': 2},
#  {'title': 'Larry Kramer in Love and Anger', 'year': 2015, 'count': 2},
#  {'title': 'Jack Goes Boating', 'year': 2010, 'count': 2},
#  {'title': "Child's Play 2", 'year': 1990, 'count': 2},
#  {'title': 'The Mangler', 'year': 1995, 'count': 2},
#  {'title': 'Bang the Drum Slowly', 'year': 1973, 'count': 2},
#  {'title': 'Jekyll & Hyde', 'year': 1990, 'count': 2},
#  {'title': 'A Little Help', 'year': 2010, 'count': 2},
#  {'title': 'Catch That Kid', 'year': 2004, 'count': 2},
#  {'title': 'Wings of Desire', 'year': 1987, 'count': 2},
#  {'title': 'Fixing Frank', 'year': 2002, 'count': 2},
#  {'title': 'Helter Skelter', 'year': 2012, 'count': 2},
#  {'title': 'Never Met Picasso', 'year': 1996, 'count': 2},
#  {'title': "A Knight's Tale", 'year': 2001, 'count': 2},
#  {'title': 'S.O.B.', 'year': 1981, 'count': 2},
#  {'title': 'We Steal Secrets: The Story of WikiLeaks',
#   'year': 2013,
#   'count': 2},
#  {'title': 'My Little Business', 'year': 1999, 'count': 2},
#  {'title': 'Mister Johnson', 'year': 1990, 'count': 2},
#  {'title': 'Cinderfella', 'year': 1960, 'count': 2},
#  {'title': 'Primal Fear', 'year': 1996, 'count': 2},
#  {'title': 'Delbaran', 'year': 2001, 'count': 2},
#  {'title': 'Melissa P.', 'year': 2005, 'count': 2},
#  {'title': 'The Corruptor', 'year': 1999, 'count': 2},
#  {'title': 'The Adultress', 'year': 1953, 'count': 2},
#  {'title': 'Transistor Love Story', 'year': 2001, 'count': 2},
#  {'title': 'Mouth to Mouth', 'year': 2005, 'count': 2},
#  {'title': 'The Wonderful, Horrible Life of Leni Riefenstahl',
#   'year': 1993,
#   'count': 2},
#  {'title': 'The Player', 'year': 1992, 'count': 2},
#  {'title': 'Better Than Chocolate', 'year': 1999, 'count': 2},
#  {'title': 'The Out of Towners', 'year': 1970, 'count': 2},
#  {'title': 'Maledimiele', 'year': 2011, 'count': 2},
#  {'title': 'Ride a Crooked Trail', 'year': 1958, 'count': 2},
#  {'title': 'Bungee Jumping of Their Own', 'year': 2001, 'count': 2},
#  {'title': 'Dancemaker', 'year': 1998, 'count': 2},
#  {'title': 'City Heat', 'year': 1984, 'count': 2},
#  {'title': 'Phobia 2', 'year': 2009, 'count': 2},
#  {'title': '28 Up', 'year': 1984, 'count': 2},
#  {'title': 'Azzurro', 'year': 2000, 'count': 2},
#  {'title': 'Igor', 'year': 2008, 'count': 2},
#  {'title': 'Oktober November', 'year': 2013, 'count': 2},
#  {'title': 'Two Deaths', 'year': 1995, 'count': 2},
#  {'title': 'Nokas', 'year': 2010, 'count': 2},
#  {'title': 'Road House', 'year': 1989, 'count': 2},
#  {'title': 'Auk Nr. 8', 'year': 2010, 'count': 2},
#  {'title': '21', 'year': 2008, 'count': 2},
#  {'title': 'The Rain People', 'year': 1969, 'count': 2},
#  {'title': 'The Tough Ones', 'year': 1999, 'count': 2},
#  {'title': 'Bessie', 'year': 2015, 'count': 2},
#  {'title': 'La dèsenchantèe', 'year': 1990, 'count': 2},
#  {'title': 'The Policeman', 'year': 1971, 'count': 2},
#  {'title': 'Suspect X', 'year': 2008, 'count': 2},
#  {'title': 'Drive Thru', 'year': 2007, 'count': 2},
#  {'title': 'The Boxcar Children', 'year': 2014, 'count': 2},
#  {'title': 'Erebus: Into the Unknown', 'year': 2014, 'count': 2},
#  {'title': "The Tiger's Tail", 'year': 2006, 'count': 2},
#  {'title': 'The Dirt Bike Kid', 'year': 1985, 'count': 2},
#  {'title': 'Ghost World', 'year': 2001, 'count': 2},
#  {'title': 'Terminator Genisys', 'year': 2015, 'count': 2},
#  {'title': 'Yesterday Was a Lie', 'year': 2008, 'count': 2},
#  {'title': 'Islander', 'year': 2007, 'count': 2},
#  {'title': 'Lad: A Yorkshire Story', 'year': 2013, 'count': 2},
#  {'title': 'Commando', 'year': 2013, 'count': 2},
#  {'title': 'A City of Sadness', 'year': 1989, 'count': 2},
#  {'title': 'Spun', 'year': 2002, 'count': 2},
#  {'title': "Cutter's Way", 'year': 1981, 'count': 2},
#  {'title': 'Pyaar Impossible!', 'year': 2010, 'count': 2},
#  {'title': 'Zindagi Na Milegi Dobara', 'year': 2011, 'count': 2},
#  {'title': 'Gas, Inspector Palmu!', 'year': 1961, 'count': 2},
#  {'title': 'The Floating Castle', 'year': 2012, 'count': 2},
#  {'title': 'Crime + Punishment in Suburbia', 'year': 2000, 'count': 2},
#  {'title': 'If I Were You 2', 'year': 2009, 'count': 2},
#  {'title': 'Joe Hill', 'year': 1971, 'count': 2},
#  {'title': 'Girl Fight', 'year': 2011, 'count': 2},
#  {'title': 'The Green Pastures', 'year': 1936, 'count': 2},
#  {'title': 'Tremors 3: Back to Perfection', 'year': 2001, 'count': 2},
#  {'title': 'Bionicle 2: Legends of Metru Nui', 'year': 2004, 'count': 2},
#  {'title': 'My Life Without Me', 'year': 2003, 'count': 2},
#  {'title': 'Sand Castles', 'year': 2014, 'count': 2},
#  {'title': 'Sammy and Me', 'year': 2002, 'count': 2},
#  {'title': 'White Lion', 'year': 2010, 'count': 2},
#  {'title': 'No Good Deed', 'year': 2002, 'count': 2},
#  {'title': 'Latter Days', 'year': 2003, 'count': 2},
#  {'title': 'Como agua para chocolate', 'year': 1992, 'count': 2},
#  {'title': 'The Mirror', 'year': 1997, 'count': 2},
#  {'title': 'The Paper Brigade', 'year': 1996, 'count': 2},
#  {'title': 'Girl Walks Into a Bar', 'year': 2011, 'count': 2},
#  {'title': 'In the Name of the Pope King', 'year': 1977, 'count': 2},
#  {'title': 'All the Wilderness', 'year': 2014, 'count': 2},
#  {'title': 'Lucky Luke', 'year': 1991, 'count': 2},
#  {'title': 'Love Without Pity', 'year': 1989, 'count': 2},
#  {'title': 'Jitters', 'year': 2010, 'count': 2},
#  {'title': 'Crows Zero', 'year': 2007, 'count': 2},
#  {'title': 'Mèbius', 'year': 2013, 'count': 2},
#  {'title': 'Lakota Woman: Siege at Wounded Knee', 'year': 1994, 'count': 2},
#  {'title': 'El amor brujo', 'year': 1986, 'count': 2},
#  ...]

# %% [markdown]
# #### Задача 2.2 — **1 балл**

# %% [markdown]
# Используя данные, полученные в задаче 2.1, выведите на экран столбчатую диаграмму, показывающую топ-20 наиболее комментируемых фильмов. По оси ординат выведите названия этих фильмов (подписи разместите слева диаграммы), по оси абсцисс — количество комментариев.
#
# Для решения задачи можно использовать любую библиотеку, например Seaborn или Matplotlib.

# %%
# Ваш код здесь
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


result = client['sample_mflix']['comments'].aggregate(query)
movies = list(result)
counts = [movie['count'] for movie in movies[:20]]
names = [movie['title'] for movie in movies[:20]]
df = pd.DataFrame(list(zip(names, counts)), columns=['names', 'counts'])

fig = plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
plt.ylabel('Название фильма')
plt.xlabel('Количество комментариев')
barplot = sns.barplot(data=df, y='names', x='counts', hue='names', palette='rocket', orient='h')
for cont in barplot.containers:
    barplot.bar_label(cont, fontsize=10)
barplot.set_title("Топ-20 наиболее комментируемых фильмов");
